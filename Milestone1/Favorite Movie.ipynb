# %%
import pickle
import seaborn
import numpy as np
import httplib
import json
from skimage import io
from imdb import IMDb
import pandas as pd

# %% [markdown]
# # Fantastic World!

# %% [markdown]
# - Search by name

# %%
ia = IMDb(accessSystem= 'http' )
search_movie = ia.search_movie('Fantastic Beasts and Where to Find Them')

# %%
search_movie
# Out:
# [<Movie id:3183660[http] title:_Fantastic Beasts and Where to Find Them (2016)_>,
#  <Movie id:6677432[http] title:_"Fantastic Beasts and Where to Find Them (2016) (TV Episode)  - Season 1 | Episode 12  - The Dom Reviews" (2014)_>,
#  <Movie id:4123430[http] title:_Fantastic Beasts and Where to Find Them 2 (2018)_>,
#  <Movie id:4123432[http] title:_Fantastic Beasts and Where to Find Them 3 (2020)_>,
#  <Movie id:6149054[http] title:_Fantastic Beasts and Where to Find Them 5 (2024)_>,
#  <Movie id:6149052[http] title:_Fantastic Beasts and Where to Find Them 4 (2022)_>,
#  <Movie id:4940424[http] title:_"Fantastic Beasts and Where to Find Them/Bleed for This/The Edge of Seventeen/Manchester by the Sea (2016) (TV Episode)  - Season 12 | Episode 10  - Made in Hollywood" (2005)_>,
#  <Movie id:6709962[http] title:_"Fantastic Beasts & Where to Find Them (2017) (TV Episode)  - Season 6 | Episode 13  - Honest Trailers" (2012)_>,
#  <Movie id:6241668[http] title:_"Cast of "Fantastic Beasts and Where to Find Them" (2016) (TV Episode)  - Season 20 | Episode 54  - The View" (1997)_>,
#  <Movie id:6650328[http] title:_The Battle for Diagon Alley: A Fantastic Beasts and Where to Find Them Fan Film (2016)_>,
#  <Movie id:6257624[http] title:_"Fantastic Beasts and Where to Find Them/The Edge of Seventeen (2016) (TV Episode)  - Season 6 | Episode 99  - Midnight Screenings" (2011)_>]

# %% [markdown]
# - Get ID and Extract information by ID

# %%
#IMDb
favorite_movie_imdb = ia.get_movie(3183660) 
print favorite_movie_imdb
print "Genres from IMDb: ", favorite_movie_imdb['genres']
# Out:
# Fantastic Beasts and Where to Find Them
# Genres from IMDb:  [u'Adventure', u'Family', u'Fantasy']

# %%
io.imshow(io.imread(favorite_movie_imdb['full-size cover url']))
io.show()

# %%
#TMDb
def tmdb_request(url):
    api_key = "&api_key=7fbe755e9e83c66a573c6482cefd23ed"
    conn = httplib.HTTPSConnection("api.themoviedb.org")
    conn.request("GET", url + api_key)
    res = conn.getresponse()
    data = res.read()
    j = json.loads(data)
    return j

def tmdb_get_movie_by_imdb_id(imdb_id):
    api_key = "7fbe755e9e83c66a573c6482cefd23ed"
    conn = httplib.HTTPSConnection("api.themoviedb.org")
    conn.request("GET", 
                 "/3/find/tt"+str(imdb_id)+"?api_key="+api_key+"&external_source=imdb_id", 
                 "{}")
    data = json.loads(conn.getresponse().read().decode("utf-8"))
    tmdb_id = data['movie_results'][0]['id']
    return tmdb_get_movie_by_tmdb_id(tmdb_id)
    
def tmdb_get_movie_by_tmdb_id(tmdb_id):
    api_key = "7fbe755e9e83c66a573c6482cefd23ed"
    conn = httplib.HTTPSConnection("api.themoviedb.org")
    conn.request("GET", 
                 "/3/movie/"+str(tmdb_id)+"?api_key="+api_key, 
                 "{}")
    return conn.getresponse().read().decode("utf-8")
def tmdb_get_poster_url(path):
    return "https://image.tmdb.org/t/p/w500" + path

# %%
favorite_movie_tmdb = json.loads(tmdb_get_movie_by_imdb_id(3183660))

# %%
favorite_movie_tmdb['genres']
# Out:
# [{u'id': 12, u'name': u'Adventure'},
#  {u'id': 28, u'name': u'Action'},
#  {u'id': 14, u'name': u'Fantasy'}]

# %%
url = tmdb_get_poster_url(favorite_movie_tmdb['poster_path'])

# %%
io.imshow(io.imread(url))
io.show()

# %% [markdown]
# # Top 10 popular movies of 2016

# %%
#get top 10 popular movies of 2016 using discover
popular_2016 = tmdb_request("/3/discover/movie?primary_release_year=2016&sort_by=popularity.desc")
print popular_2016.keys()
popular_2016_top_10 = popular_2016['results'][:10]
# Out:
# [u'total_results', u'total_pages', u'page', u'results']

# %%
for m in popular_2016_top_10:
    title = m['title']
    ID = m['id']
    genre_dict = json.loads(tmdb_get_movie_by_tmdb_id(ID))['genres'] #get details by ID and retrieve genres
    genre_list =  [str(ele['name']) for ele in genre_dict] #transrform into a nicer form
    print title, genre_list #print result
# Out:
# Sing ['Animation', 'Comedy', 'Drama', 'Family', 'Music']
# Fantastic Beasts and Where to Find Them ['Adventure', 'Action', 'Fantasy']
# Finding Dory ['Adventure', 'Animation', 'Comedy', 'Family']
# Arrival ['Drama', 'Science Fiction']
# Deadpool ['Action', 'Adventure', 'Comedy', 'Romance']
# Captain America: Civil War ['Action', 'Science Fiction']
# Rogue One: A Star Wars Story ['Action', 'Drama', 'Science Fiction', 'War']
# Underworld: Blood Wars ['Action', 'Horror']
# Doctor Strange ['Action', 'Adventure', 'Fantasy', 'Science Fiction']
# X-Men: Apocalypse ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %% [markdown]
# # Compare Info from IMDb and TMDb

# %%
{ele: favorite_movie_imdb[ele] for ele in favorite_movie_imdb.keys()}
# Out:
# {'akas': [u'Animales fant\xe1sticos y d\xf3nde encontrarlos::Chile (imdb display title), Mexico (imdb display title), Spain (imdb display title), Uruguay (3-D version)',
#   u'\u03a6\u03b1\u03bd\u03c4\u03b1\u03c3\u03c4\u03b9\u03ba\u03ac \u03b6\u03ce\u03b1 \u03ba\u03b1\u03b9 \u03c0\u03bf\u03cd \u03b2\u03c1\u03af\u03c3\u03ba\u03bf\u03bd\u03c4\u03b1\u03b9::Greece',
#   u'\u0424\u0430\u043d\u0442\u0430\u0441\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u0442\u0432\u0430\u0440\u0438 \u0438 \u0433\u0434\u0435 \u043e\u043d\u0438 \u043e\u0431\u0438\u0442\u0430\u044e\u0442::Russia',
#   u'\u0424\u0430\u043d\u0442\u0430\u0441\u0442\u0438\u0447\u043d\u0438 \u0436\u0438\u0432\u043e\u0442\u043d\u0438 \u0438 \u043a\u044a\u0434\u0435 \u0434\u0430 \u0433\u0438 \u043d\u0430\u043c\u0435\u0440\u0438\u043c::Bulgaria (Bulgarian title)',
#   u'\u0424\u0430\u043d\u0442\u0430\u0441\u0442\u0438\u0447\u043di \u0437\u0432i\u0440i i \u0434\u0435 i\u0445 \u0448\u0443\u043a\u0430\u0442\u0438::Ukraine',
#   u'Animais Fant\xe1sticos e Onde Habitam::Brazil (imdb display title)',
#   u'Animales Fant\xe1sticos y d\xf3nde encontrarlos::Argentina (imdb display title)',
#   u'Animali fantastici e dove trovarli::Italy (imdb display title)',
#   u'B\xe8sties fant\xe0stiques i on trobar-les::Spain (Catalan title) (imdb display title)',
#   u'Cudesne zvijeri i gdje ih naci::Croatia (imdb display title)',
#   u'Fabeldyr og hvor de er \xe5 finne::Norway (imdb display title)',
#   u'Fantasti\u010dne zveri i gde ih na\u0107i::Serbia',
#   u'Fantastik Canavarlar Nelerdir Nerede Bulunurlar::Turkey (Turkish title) (alternative title)',
#   u'Fantastilised elukad ja kust neid leida::Estonia (imdb display title)',
#   u'Fantastiniai gyvunai ir kur juos rasti::Lithuania (imdb display title)',
#   u'Fantastiska vidunder och var man hittar dem::Sweden (imdb display title)',
#   u'Fantastiske skabninger og hvor de findes::Denmark (imdb display title)',
#   u'Fantastyczne zwierz\u0119ta i jak je znale\u017a\u0107::Poland',
#   u'Ihmeotukset ja niiden olinpaikat::Finland (imdb display title)',
#   u"Ka'yot ha'pele ve'hey'khan limtzo otan::Israel (Hebrew title) (imdb display title)",
#   u'Legend\xe1s \xe1llatok \xe9s megfigyel\xe9s\xfck::Hungary (imdb display title)',
#   u'Les animaux fantastiques::France (imdb display title)',
#   u'Magi\u010dne \u017eivali::Slovenia',
#   u'Monstros Fant\xe1sticos e Onde Encontr\xe1-los::Portugal (imdb display title)',
#   u'Phantastische Tierwesen und wo sie zu finden sind::Germany (imdb display title)',
#   u'Sinbihan Dongmulsajeon (Mysterious Animal Dictionary)::South Korea (imdb display title)',
#   u'Sinh Vat Huyen Bi::Vietnam (imdb display title)'],
#  u'animation department': [<Person id:8611573[http] name:_Abad, Florine_>,
#   <Person id:7128880[http] name:_Affronti, Mauro_>,
#   <Person id:4556106[http] name:_Alvarado, Jhon_>,
#   <Person id:8635129[http] name:_Augello, Michael_>,
#   <Person id:4727413[http] name:_Barbier, Adrien_>,
#   <Person id:2783443[http] name:_Bates, Eric_>,
#   <Person id:4870401[http] name:_Boyoko, Krzysztof_>,
#   <Person id:4870508[http] name:_Braine, Nikki_>,
#   <Person id:5394007[http] name:_Cabana, Nicholas_>,
#   <Person id:2196914[http] name:_Caudeville, Vincent_>,
#   <Person id:5884421[http] name:_Cheong, Benjamin_>,
#   <Person id:1652103[http] name:_Conly, Sean_>,
#   <Person id:0204778[http] name:_Davis, Jay N._>,
#   <Person id:6442621[http] name:_de Lanteuil, Felipe_>,
#   <Person id:3740997[http] name:_Deerfield, Aaron_>,
#   <Person id:8703395[http] name:_Dogan, Fatih_>,
#   <Person id:3447948[http] name:_Falero, Fernando_>,
#   <Person id:0280340[http] name:_Fitzgerald, Nathan_>,
#   <Person id:6695637[http] name:_Florez, Juan Sebastian Niño_>,
#   <Person id:6225316[http] name:_Fromstein, Hayley_>,
#   <Person id:7117815[http] name:_Gutierrez, Lae_>,
#   <Person id:1024475[http] name:_Hemmings, Robert_>,
#   <Person id:7639012[http] name:_Hibbert, Naomi_>,
#   <Person id:7373542[http] name:_Jepsen, Dennis_>,
#   <Person id:4863766[http] name:_Kocanaogullari, Aziz_>,
#   <Person id:6226264[http] name:_Krook, Kolby_>,
#   <Person id:3727153[http] name:_Kurian, Geoge Meppadath_>,
#   <Person id:5812944[http] name:_Cocq, Andy Le_>,
#   <Person id:1233210[http] name:_Lentz, Chris_>,
#   <Person id:3735669[http] name:_Lin, Sandra_>,
#   <Person id:2551101[http] name:_Mahboob, Sherin_>,
#   <Person id:8635133[http] name:_Mancini, Derek_>,
#   <Person id:2983912[http] name:_Marshall, Christopher_>,
#   <Person id:1636615[http] name:_McEvoy, Colin_>,
#   <Person id:6399275[http] name:_Mills, Andrew_>,
#   <Person id:4674255[http] name:_Moranne, Benoit_>,
#   <Person id:8034464[http] name:_Sethuraman, Rameshbabu Morkonda_>,
#   <Person id:6947518[http] name:_Orduña, Oriol Navarro_>,
#   <Person id:8403617[http] name:_Prykhodko, Hennadii_>,
#   <Person id:8612941[http] name:_Richard, Maxime_>,
#   <Person id:4047764[http] name:_Roberts, Ed_>,
#   <Person id:5828142[http] name:_Sallman, Samer_>,
#   <Person id:6244219[http] name:_Seale, Kat_>,
#   <Person id:4845731[http] name:_Sendon, Amy_>,
#   <Person id:0819868[http] name:_Spruce, Kevin_>,
#   <Person id:5724178[http] name:_Tarrant, Joe_>,
#   <Person id:2808739[http] name:_Thomas, Nathan_>,
#   <Person id:6282259[http] name:_Topsy, Milian_>,
#   <Person id:0652017[http] name:_Urretabizkaia, Oskar_>,
#   <Person id:7547948[http] name:_Vicik, Ryan_>,
#   <Person id:3024948[http] name:_Wang, Lisa_>,
#   <Person id:8682222[http] name:_White, Darryl_>,
#   <Person id:7981646[http] name:_Zhao, Xin_>],
#  u'art department': [<Person id:3897264[http] name:_Adamson, Katie_>,
#   <Person id:2790838[http] name:_Aitken, Alex_>,
#   <Person id:5817392[http] name:_Allan, Oscar_>,
#   <Person id:8621362[http] name:_Arthur, Ellyn_>,
#   <Person id:2828509[http] name:_Arthur, Huw_>,
#   <Person id:1628897[http] name:_Asbury, Giles_>,
#   <Person id:0962641[http] name:_Austin, Suzanne_>,
#   <Person id:3313114[http] name:_Best, Lucy_>,
#   <Person id:4361905[http] name:_Bick, Emily_>,
#   <Person id:0088528[http] name:_Bliss, Rob_>,
#   <Person id:7584894[http] name:_Cannon, Emily_>,
#   <Person id:0146211[http] name:_Catling, Paul_>,
#   <Person id:6378162[http] name:_Channon, Robert_>,
#   <Person id:2535791[http] name:_Cheal, Richard_>,
#   <Person id:0154921[http] name:_Cheesman, Paul_>,
#   <Person id:8654590[http] name:_Clark, Philip_>,
#   <Person id:3140776[http] name:_Clerkin, Stephanie_>,
#   <Person id:2763267[http] name:_Clough, Emma_>,
#   <Person id:0177472[http] name:_Cooke, Matt_>,
#   <Person id:0180427[http] name:_Cornish, Jim_>,
#   <Person id:0183753[http] name:_Court, Bryn_>,
#   <Person id:6574375[http] name:_Coxon, Tom_>,
#   <Person id:8773800[http] name:_Craston, Matilda_>,
#   <Person id:8473132[http] name:_Cullane, James_>,
#   <Person id:3896600[http] name:_Daily, Sarah Elizabeth_>,
#   <Person id:2870169[http] name:_Davis, Peter_>,
#   <Person id:3899197[http] name:_Dibble, Brooke_>,
#   <Person id:1672863[http] name:_Downing, Jonathan_>,
#   <Person id:7004939[http] name:_Dray, Sally_>,
#   <Person id:1279171[http] name:_Dubeau, Mark_>,
#   <Person id:0254070[http] name:_Ellers, Sander_>,
#   <Person id:3133624[http] name:_Elms, Scott_>,
#   <Person id:4549456[http] name:_Fisher, Kevin_>,
#   <Person id:5523918[http] name:_Forsythe, Natalie_>,
#   <Person id:4362472[http] name:_Fuller, Laura_>,
#   <Person id:5346054[http] name:_Gardner, Tom_>,
#   <Person id:8845228[http] name:_Gonzalez, Jos_>,
#   <Person id:6574498[http] name:_Gorman, Lucy Samantha_>,
#   <Person id:0331517[http] name:_Gosling, Simon_>,
#   <Person id:3299505[http] name:_Hall, Jake_>,
#   <Person id:6814788[http] name:_Halliday, Alí_>,
#   <Person id:7375498[http] name:_Haskett, Sean_>,
#   <Person id:0376939[http] name:_Hendy, James_>,
#   <Person id:2242547[http] name:_Hervieu, Sophie_>,
#   <Person id:5081197[http] name:_Hodgson, Andrew_>,
#   <Person id:1175695[http] name:_Howe, Lucy_>,
#   <Person id:2306842[http] name:_Howton, Darren_>,
#   <Person id:6154396[http] name:_James, Harry_>,
#   <Person id:5102066[http] name:_Kealy, Josie_>,
#   <Person id:0454427[http] name:_King, Alex_>,
#   <Person id:0454883[http] name:_King, John_>,
#   <Person id:0455069[http] name:_King, Michael_>,
#   <Person id:8651382[http] name:_Kirsop, Ross_>,
#   <Person id:6009629[http] name:_Koroscik, Karl_>,
#   <Person id:2350332[http] name:_Kyriacou, Angela_>,
#   <Person id:7146674[http] name:_Lamb, Eleanor_>,
#   <Person id:1645650[http] name:_Lima, Eduardo_>,
#   <Person id:2955983[http] name:_Malynn, Charlotte_>,
#   <Person id:5192387[http] name:_Mathiszig-Lee, Lily_>,
#   <Person id:5862227[http] name:_McCausland, Albert_>,
#   <Person id:0567703[http] name:_McDonald, Christian_>,
#   <Person id:3207021[http] name:_Merchant, Ossie_>,
#   <Person id:0590876[http] name:_Mina, Miraphora_>,
#   <Person id:3483195[http] name:_Molyneaux, Stephen_>,
#   <Person id:1037077[http] name:_Morison, David_>,
#   <Person id:4750134[http] name:_Murray, Kate_>,
#   <Person id:2537148[http] name:_Needs, Pippa_>,
#   <Person id:8142023[http] name:_Newman, Kirsty_>,
#   <Person id:1126927[http] name:_Newman, Sophie_>,
#   <Person id:0630107[http] name:_Niclas, Mitch_>,
#   <Person id:4216986[http] name:_Nicolaisen, Renate_>,
#   <Person id:0634705[http] name:_Noonan, Billy_>,
#   <Person id:3464496[http] name:_Onsrud, Eva_>,
#   <Person id:0652354[http] name:_Osterholzer, Wolfgang_>,
#   <Person id:0655459[http] name:_Packard, David_>,
#   <Person id:1721999[http] name:_Parker, Claudia_>,
#   <Person id:1391114[http] name:_Pettett, Amanda_>,
#   <Person id:1712260[http] name:_Pollington, Heather_>,
#   <Person id:1465402[http] name:_Popken, Peter_>,
#   <Person id:0694391[http] name:_Power, Dermot_>,
#   <Person id:5914731[http] name:_Ralph, Vicky_>,
#   <Person id:8060125[http] name:_Reynolds, Lewis_>,
#   <Person id:7185778[http] name:_Robinson, Maisie_>,
#   <Person id:8823335[http] name:_Rowlands, Ellie_>,
#   <Person id:3494604[http] name:_Salkeld, Jack_>,
#   <Person id:6190477[http] name:_Schurr, Katy_>,
#   <Person id:8201424[http] name:_Sears, Ross_>,
#   <Person id:7809832[http] name:_Seath, Mark_>,
#   <Person id:3553617[http] name:_Seath, Pollyanna_>,
#   <Person id:4479106[http] name:_Shepherdly, Adam_>,
#   <Person id:0795036[http] name:_Short, Christian_>,
#   <Person id:4791400[http] name:_Silver, Corrine_>,
#   <Person id:0810072[http] name:_Smith, Suzanna_>,
#   <Person id:2261235[http] name:_Sole, Molly_>,
#   <Person id:3497878[http] name:_Spencer, James M._>,
#   <Person id:5601600[http] name:_Supplies, Bgi_>,
#   <Person id:5488864[http] name:_Tajima, Kouji_>,
#   <Person id:4116322[http] name:_Tarry, Craig_>,
#   <Person id:4628446[http] name:_Theobald, Charis_>,
#   <Person id:4389739[http] name:_Tobin, Jenny_>,
#   <Person id:3226976[http] name:_Todd, Rebecca_>,
#   <Person id:1850741[http] name:_Trunk, Marc_>,
#   <Person id:3567092[http] name:_Valette, Arnaud_>,
#   <Person id:2876385[http] name:_Vickerman, Rowena_>,
#   <Person id:4384453[http] name:_Walker, Cara_>,
#   <Person id:1392179[http] name:_Walker, Julian_>,
#   <Person id:0920245[http] name:_Wells, Jake_>,
#   <Person id:1240541[http] name:_Wescott, Paul_>,
#   <Person id:6086390[http] name:_Westover, Darren_>,
#   <Person id:8035604[http] name:_Wheeler, Lizzy_>,
#   <Person id:4996521[http] name:_White, Candice_>,
#   <Person id:0929345[http] name:_Wilkinson, Ben_>,
#   <Person id:3174770[http] name:_Wilkinson, Buddie_>,
#   <Person id:0931232[http] name:_Williams, Marcus_>,
#   <Person id:7217669[http] name:_Williams, Sam_>,
#   <Person id:4038032[http] name:_Wingrove, Thomas_>,
#   <Person id:5126662[http] name:_Young, Andy_>,
#   <Person id:1823779[http] name:_Young, Dorrie_>,
#   <Person id:2635705[http] name:_Zawadzki, Ian_>,
#   <Person id:6972258[http] name:_Burgess, Mark_>,
#   <Person id:8780757[http] name:_Hinsley, Lucy_>],
#  'art direction': [<Person id:0020151[http] name:_Allday, David_>,
#   <Person id:0103245[http] name:_Bradley, Guy_>,
#   <Person id:1087647[http] name:_Britton, Toby_>,
#   <Person id:0233796[http] name:_Dorme, Peter_>,
#   <Person id:1184878[http] name:_Fitch, Gavin_>,
#   <Person id:0284192[http] name:_Foley, Martin_>,
#   <Person id:0342177[http] name:_Grimble, Kate_>,
#   <Person id:0399125[http] name:_Huband, Christian_>,
#   <Person id:1275459[http] name:_Street, Hayley Easton_>,
#   <Person id:0866777[http] name:_Tomkins, Leslie_>],
#  'aspect ratio': u'1.85 : 1',
#  'assistant director': [<Person id:0108305[http] name:_Brewster, Tom_>,
#   <Person id:4507020[http] name:_Broadfoot, Rory_>,
#   <Person id:2254739[http] name:_Browne, Tom_>,
#   <Person id:1170389[http] name:_Carroll, Glen_>,
#   <Person id:0168362[http] name:_Cockren, Mark_>,
#   <Person id:8145865[http] name:_Cooksley, Carrie_>,
#   <Person id:7393393[http] name:_Dennis, Charlie_>,
#   <Person id:0285902[http] name:_Ford, Toby_>,
#   <Person id:0299555[http] name:_Fysh, Dominic_>,
#   <Person id:6291195[http] name:_Gainsbury, Chris_>,
#   <Person id:4306870[http] name:_Gallacher, Stephen_>,
#   <Person id:3818484[http] name:_Guest, Harry_>,
#   <Person id:1894855[http] name:_Hall, Freddie_>,
#   <Person id:4879317[http] name:_Hillary, Daniel_>,
#   <Person id:4440555[http] name:_Hingst, Katharina_>,
#   <Person id:3843835[http] name:_Hitchcock, Annie_>,
#   <Person id:0003054[http] name:_Howard, Ben_>,
#   <Person id:0397701[http] name:_Howarth, Ben_>,
#   <Person id:5343451[http] name:_Irvine, Alex_>,
#   <Person id:7146302[http] name:_Jordan, Lucy C._>,
#   <Person id:5091748[http] name:_Lizaitis, Danni_>,
#   <Person id:1174595[http] name:_Madden, Terence_>,
#   <Person id:2827444[http] name:_Mannerings, Guy_>,
#   <Person id:0549261[http] name:_Marlowe, Candy_>,
#   <Person id:7432808[http] name:_Miles, Charlotte Amelia_>,
#   <Person id:6966911[http] name:_Miles, Georgina_>,
#   <Person id:0643005[http] name:_Oakley, Alex_>,
#   <Person id:2782971[http] name:_Quirk, Ben_>,
#   <Person id:3950425[http] name:_Rickwood, Jason_>,
#   <Person id:0731913[http] name:_Robertson, Josh_>,
#   <Person id:4571527[http] name:_Scarisbrick, Jack_>,
#   <Person id:4439731[http] name:_Shakespeare, Barney_>,
#   <Person id:7483405[http] name:_Sowerby, David_>,
#   <Person id:4845951[http] name:_Stone, Siggy_>,
#   <Person id:4845951[http] name:_Stone, Siggy_>,
#   <Person id:3905417[http] name:_Waggett, Patrick_>,
#   <Person id:3795617[http] name:_Watson, Vanluke_>,
#   <Person id:7384151[http] name:_Wood, Jacob_>,
#   <Person id:0941189[http] name:_Woolfenden, Stephen_>],
#  'camera and electrical department': [<Person id:5335035[http] name:_Adams, Ryan S._>,
#   <Person id:7792147[http] name:_Andrews, Josh_>,
#   <Person id:0038727[http] name:_Ashby, David_>,
#   <Person id:2064446[http] name:_Bailey, Darren_>,
#   <Person id:1022617[http] name:_Baker, Simon_>,
#   <Person id:5120541[http] name:_Baker, Simon_>,
#   <Person id:8339667[http] name:_Benjamin, Lincoln_>,
#   <Person id:3808211[http] name:_Bentley, Jack_>,
#   <Person id:6677091[http] name:_Berglund, Michael_>,
#   <Person id:1765234[http] name:_Berman, Jason_>,
#   <Person id:4651797[http] name:_Bridges, Alexander_>,
#   <Person id:0108798[http] name:_Bridges, Stuart_>,
#   <Person id:0119687[http] name:_Buitendijk, Jaap_>,
#   <Person id:2236906[http] name:_Catto, Abigail_>,
#   <Person id:3407735[http] name:_Claridge, Andres_>,
#   <Person id:1991636[http] name:_Clark, Rachel_>,
#   <Person id:6605122[http] name:_Clements, Dave_>,
#   <Person id:2641377[http] name:_Cook, Theo_>,
#   <Person id:5400009[http] name:_Cooke, Ashley_>,
#   <Person id:1615327[http] name:_Cupac, Nic_>,
#   <Person id:2354149[http] name:_Dean, Tim_>,
#   <Person id:3193393[http] name:_Deeks, Oscar_>,
#   <Person id:1973243[http] name:_Dennis, Jonathan_>,
#   <Person id:7275273[http] name:_Donnelly, Ryan_>,
#   <Person id:6175353[http] name:_Jr., John Donohue_>,
#   <Person id:0254173[http] name:_Ellingworth, Steve_>,
#   <Person id:1733767[http] name:_Elvin, Harry_>,
#   <Person id:1209672[http] name:_Ewart, Jason_>,
#   <Person id:0277400[http] name:_Finch, Chuck_>,
#   <Person id:0277468[http] name:_Finch, Wick_>,
#   <Person id:1103340[http] name:_Finch, Will_>,
#   <Person id:5832186[http] name:_Fox, George Anthony_>,
#   <Person id:3031026[http] name:_Fraser, Phoebe_>,
#   <Person id:8577425[http] name:_Gardner, Leigh_>,
#   <Person id:0322806[http] name:_Glickman, Max_>,
#   <Person id:1700053[http] name:_Gossart, Jean-Philippe_>,
#   <Person id:1700053[http] name:_Gossart, Jean-Philippe_>,
#   <Person id:1016827[http] name:_Hartley, Dan_>,
#   <Person id:8017228[http] name:_Haughey, Rowan_>,
#   <Person id:8017228[http] name:_Haughey, Rowan_>,
#   <Person id:5041054[http] name:_Hayes, Samuel_>,
#   <Person id:4659188[http] name:_Hayley-Barker, Peter_>,
#   <Person id:1900036[http] name:_Hideg, Steve_>,
#   <Person id:6810382[http] name:_Howlett, Wayne_>,
#   <Person id:2217319[http] name:_Hughes, Charlie_>,
#   <Person id:1963631[http] name:_Hurley, Stuart_>,
#   <Person id:2016691[http] name:_Hymns, Paul_>,
#   <Person id:2016691[http] name:_Hymns, Paul_>,
#   <Person id:2335425[http] name:_Knight, Jody_>,
#   <Person id:7190512[http] name:_Langston, Harry_>,
#   <Person id:0488367[http] name:_Larner, Brad_>,
#   <Person id:4178987[http] name:_Lloyd, Stephen_>,
#   <Person id:5880711[http] name:_MacGregor, Lisa_>,
#   <Person id:6519705[http] name:_March, Ryan_>,
#   <Person id:6519705[http] name:_March, Ryan_>,
#   <Person id:4144481[http] name:_Marsden, Joe_>,
#   <Person id:0550458[http] name:_Marsden, Peter_>,
#   <Person id:0558789[http] name:_Mathie, Stephen_>,
#   <Person id:0568895[http] name:_McGahon, Vince_>,
#   <Person id:0568895[http] name:_McGahon, Vince_>,
#   <Person id:1315196[http] name:_Meere, Ray_>,
#   <Person id:3859344[http] name:_Mensah, Michael_>,
#   <Person id:0581149[http] name:_Merrell, Billy_>,
#   <Person id:0581154[http] name:_Merrell, Richard_>,
#   <Person id:1734509[http] name:_Morris, Tim_>,
#   <Person id:2623717[http] name:_Morris, Will_>,
#   <Person id:0615281[http] name:_Murray, Steve_>,
#   <Person id:8227660[http] name:_Noble, Jason_>,
#   <Person id:0634273[http] name:_Nolan, Gary_>,
#   <Person id:1280654[http] name:_O'Connor, Russell_>,
#   <Person id:4287614[http] name:_Olney, Peter_>,
#   <Person id:2260050[http] name:_Parker, Scott_>,
#   <Person id:4207719[http] name:_Perlinski, Piotr_>,
#   <Person id:2266214[http] name:_Puricelli, Michele Abramo_>,
#   <Person id:2503220[http] name:_Purvis, Elliot_>,
#   <Person id:5824228[http] name:_Quilliam, Georgia_>,
#   <Person id:3169526[http] name:_Redpath, Laura_>,
#   <Person id:2869711[http] name:_Ridout, Jack_>,
#   <Person id:4245919[http] name:_Rogers, Ben Casciello_>,
#   <Person id:8278345[http] name:_Rogers, Sean_>,
#   <Person id:0805427[http] name:_Slater, Ross_>,
#   <Person id:2763051[http] name:_Spencer, Kat_>,
#   <Person id:0822409[http] name:_Stankowski, Stefan_>,
#   <Person id:6329328[http] name:_Steven, Duncan_>,
#   <Person id:7734221[http] name:_Taylor, Giles_>,
#   <Person id:6233067[http] name:_Jr., Billy Thornhill_>,
#   <Person id:7315257[http] name:_Tooke, Joe_>,
#   <Person id:6210331[http] name:_Turner, Ryan_>,
#   <Person id:3499976[http] name:_Tyebkhan, Mustafa_>,
#   <Person id:0907683[http] name:_Walker, Derek_>,
#   <Person id:3285955[http] name:_Wall, Charlie_>,
#   <Person id:1488775[http] name:_Waving, Matthew_>,
#   <Person id:1401309[http] name:_Welch, Peter_>,
#   <Person id:1329959[http] name:_Wells, Dave_>,
#   <Person id:0924024[http] name:_Whelan, Des_>,
#   <Person id:4619492[http] name:_White, Pip_>,
#   <Person id:0934751[http] name:_Windon, Matt_>,
#   <Person id:2262186[http] name:_Wood, Steve_>,
#   <Person id:3626891[http] name:_Young-Jamieson, Harry_>],
#  'canonical title': u'Fantastic Beasts and Where to Find Them',
#  'cast': [<Person id:1519666[http] name:_Redmayne, Eddie_>,
#   <Person id:0714866[http] name:_Redford, Sam_>,
#   <Person id:2580832[http] name:_Goldman, Scott_>,
#   <Person id:0072758[http] name:_Bentinck, Tim_>,
#   <Person id:0384732[http] name:_Hill, Tom Clarke_>,
#   <Person id:0846925[http] name:_Tait, Tristan_>,
#   <Person id:0268199[http] name:_Farrell, Colin_>,
#   <Person id:0799252[http] name:_Sim, Matthew_>,
#   <Person id:2239702[http] name:_Waterston, Katherine_>,
#   <Person id:0608090[http] name:_Morton, Samantha_>,
#   <Person id:0283945[http] name:_Fogler, Dan_>,
#   <Person id:3009232[http] name:_Miller, Ezra_>,
#   <Person id:7500671[http] name:_Wood-Blagrove, Faith_>,
#   <Person id:2893183[http] name:_Murray, Jenn_>,
#   <Person id:3270798[http] name:_Peterson, Cory_>,
#   <Person id:0688351[http] name:_Pohl, Lucie_>,
#   <Person id:0106998[http] name:_Breitmayer, Peter_>,
#   <Person id:1756193[http] name:_Samuels, Jake_>,
#   <Person id:4833636[http] name:_Cazier, Max_>,
#   <Person id:0000445[http] name:_Hedaya, Dan_>,
#   <Person id:3453330[http] name:_Meyer, Christy_>,
#   <Person id:0252238[http] name:_Ejogo, Carmen_>,
#   <Person id:0666848[http] name:_Paul, Guy_>,
#   <Person id:2132319[http] name:_Paduraru, Andreea_>,
#   <Person id:4187133[http] name:_Hamonde, Walles_>,
#   <Person id:4625680[http] name:_Tipper, Dominique_>,
#   <Person id:2295590[http] name:_Guthrie, Kevin_>,
#   <Person id:8586984[http] name:_Heller, Leo_>,
#   <Person id:5391976[http] name:_Roughley, Miles_>,
#   <Person id:1469085[http] name:_Wittman, Anne_>,
#   <Person id:3689362[http] name:_Hayden, Erick_>,
#   <Person id:0083307[http] name:_Birchard, Paul_>,
#   <Person id:3995719[http] name:_Raftery, Ronan_>,
#   <Person id:0388243[http] name:_Hodgkins, Tom_>,
#   <Person id:0000685[http] name:_Voight, Jon_>,
#   <Person id:3912910[http] name:_Cowdery, Josh_>,
#   <Person id:0352705[http] name:_Haddington, Ellie_>,
#   <Person id:0837223[http] name:_Sudol, Alison_>,
#   <Person id:3106862[http] name:_Macnab, Joseph_>,
#   <Person id:3037999[http] name:_Edwards, Bart_>,
#   <Person id:0101668[http] name:_Boyce, Todd_>,
#   <Person id:8586985[http] name:_Oelbermann, Martin_>,
#   <Person id:2110418[http] name:_Chan, Gemma_>,
#   <Person id:0167134[http] name:_Clothier, Richard_>,
#   <Person id:3956045[http] name:_Dixon, Christian_>,
#   <Person id:2141398[http] name:_Gazi, Akin_>,
#   <Person id:2063366[http] name:_Hardisty, Richard_>,
#   <Person id:1150155[http] name:_Moynihan, Elizabeth_>,
#   <Person id:0114314[http] name:_Brown, Miquel_>,
#   <Person id:2148911[http] name:_Mosaku, Wunmi_>,
#   <Person id:0813066[http] name:_Solimeno, Cristian_>,
#   <Person id:8586986[http] name:_Wilson, Matthew_>,
#   <Person id:6448864[http] name:_Mulvey, Brian F._>,
#   <Person id:6422972[http] name:_Ayeh, Aretha_>,
#   <Person id:8586987[http] name:_Emmi_>,
#   <Person id:0000579[http] name:_Perlman, Ron_>,
#   <Person id:0568988[http] name:_McGaughey, Nicholas_>,
#   <Person id:2018573[http] name:_Cronin, Sean_>,
#   <Person id:2368789[http] name:_Kravitz, Zoë_>,
#   <Person id:3429884[http] name:_Kene, Arinzé_>,
#   <Person id:0675110[http] name:_Perry, Jane_>,
#   <Person id:0000136[http] name:_Depp, Johnny_>,
#   <Person id:7360494[http] name:_Adeyemi, Abi_>,
#   <Person id:7242075[http] name:_Anderson, Reid_>,
#   <Person id:6464282[http] name:_Archer, Aileen_>,
#   <Person id:6200804[http] name:_Artlett, Robert-Anthony_>,
#   <Person id:4051209[http] name:_Asquith-Coe, Lee_>,
#   <Person id:2506300[http] name:_Atkins, Lasco_>,
#   <Person id:5659608[http] name:_Austin, Alphonso_>,
#   <Person id:7328038[http] name:_Barron, Michael_>,
#   <Person id:8745734[http] name:_Beck, Roy_>,
#   <Person id:7270222[http] name:_Benanti, Marc_>,
#   <Person id:3952602[http] name:_Benham, Nathan_>,
#   <Person id:4800427[http] name:_Bergquist, Paul_>,
#   <Person id:5904446[http] name:_Bernardeschi, Laura_>,
#   <Person id:6018519[http] name:_Biscoe, David J_>,
#   <Person id:4216326[http] name:_Bolton, Lee_>,
#   <Person id:7707203[http] name:_Boor, Annarie_>,
#   <Person id:7855840[http] name:_Briand, Elizabeth_>,
#   <Person id:3364235[http] name:_Broome, Neil_>,
#   <Person id:4675234[http] name:_Brummel, Greg_>,
#   <Person id:3748567[http] name:_de Burgh, Chloe_>,
#   <Person id:1676819[http] name:_Byrne, Douglas_>,
#   <Person id:4435946[http] name:_Carbonnel, Fanny_>,
#   <Person id:6373664[http] name:_Charles-Cully, David_>,
#   <Person id:6857045[http] name:_Clegg, Stacey_>,
#   <Person id:7490539[http] name:_Collingwood, Chloe_>,
#   <Person id:7359035[http] name:_Cooper-King, Claire_>,
#   <Person id:6969178[http] name:_Cowell, Carmen_>,
#   <Person id:4604981[http] name:_Crastan, Silvia_>,
#   <Person id:6426525[http] name:_Dab, Tom_>,
#   <Person id:5583696[http] name:_Davies, Craig_>,
#   <Person id:7618414[http] name:_Davison, Nick_>,
#   <Person id:4995553[http] name:_Dewdney, Paul_>,
#   <Person id:1454287[http] name:_Dharmalingam, Rudi_>,
#   <Person id:6824061[http] name:_Diffley, Joshua_>,
#   <Person id:4519379[http] name:_Donald, Nick_>,
#   <Person id:5279790[http] name:_Douglas, Richard_>,
#   <Person id:1397732[http] name:_Douthwaite, Henry_>,
#   <Person id:7279363[http] name:_Eccles, Stephanie_>,
#   <Person id:7066645[http] name:_Farrer, Karl_>,
#   <Person id:5358559[http] name:_Fazzani, Dino_>,
#   <Person id:8052327[http] name:_Ferraco, Flor_>,
#   <Person id:6298926[http] name:_Flynn, Marketa_>,
#   <Person id:7465367[http] name:_Futers, Lobna_>,
#   <Person id:7775715[http] name:_Gabbitas, Michael_>,
#   <Person id:6231082[http] name:_Goodson, David_>,
#   <Person id:4430162[http] name:_Grace, Kirsty_>,
#   <Person id:4112921[http] name:_Grant, Rudy Valentino_>,
#   <Person id:6617606[http] name:_Gultniece, Guna_>,
#   <Person id:1735115[http] name:_Honeywill, Abigayle_>,
#   <Person id:0394017[http] name:_Hope, Luke_>,
#   <Person id:7254255[http] name:_Horvath, Kornelia_>,
#   <Person id:6055785[http] name:_Hudson, Ashley_>,
#   <Person id:3021473[http] name:_Hughes, Alan Wyn_>,
#   <Person id:7247557[http] name:_Jaep, Alex_>,
#   <Person id:5102463[http] name:_Jenkins, Ian_>,
#   <Person id:6104373[http] name:_Junior, Patrick Carney_>,
#   <Person id:7429478[http] name:_Justified, Solomon Taiwo_>,
#   <Person id:7887724[http] name:_Kalfuntzos, Lampros_>,
#   <Person id:7255532[http] name:_Kerekes, Attila G._>,
#   <Person id:8037204[http] name:_Kerrison, Simon_>,
#   <Person id:3079422[http] name:_Khoroshko, Denis_>,
#   <Person id:6980143[http] name:_Lazar, Cristian_>,
#   <Person id:7296886[http] name:_Lazarus, Adam_>,
#   <Person id:6644751[http] name:_Leman, Cole_>,
#   <Person id:5855226[http] name:_Martinez, Jorge Leon_>,
#   <Person id:7062167[http] name:_Lezemore, Adam_>,
#   <Person id:4385301[http] name:_Lomas, Keith_>,
#   <Person id:5438664[http] name:_Low-Hang, Paul_>,
#   <Person id:4479280[http] name:_MacLeod, Khristopher_>,
#   <Person id:7677013[http] name:_Malone, Joe_>,
#   <Person id:4504286[http] name:_Mandel, Alan_>,
#   <Person id:6764710[http] name:_Marsh, Christopher_>,
#   <Person id:3199692[http] name:_Marzano, Christine_>,
#   <Person id:4430776[http] name:_Meads, Pete_>,
#   <Person id:7767317[http] name:_Mihalache, Andy_>,
#   <Person id:7419291[http] name:_Montey, Arnold_>,
#   <Person id:6484472[http] name:_Muller, James M.L._>,
#   <Person id:7215816[http] name:_Munday, Paul A_>,
#   <Person id:4849769[http] name:_Murray, John_>,
#   <Person id:7590165[http] name:_O'Donnell, Dennis_>,
#   <Person id:5743934[http] name:_O'Hara, Yves_>,
#   <Person id:8018644[http] name:_Ogleby, Andrew G._>,
#   <Person id:4786733[http] name:_Osmond, Edd_>,
#   <Person id:4016944[http] name:_Owenford, Nick_>,
#   <Person id:7733402[http] name:_Parker, Andrew_>,
#   <Person id:7849387[http] name:_Peett, Alan_>,
#   <Person id:3888029[http] name:_Picciano, Gino_>,
#   <Person id:3764470[http] name:_Price, Richard_>,
#   <Person id:5320687[http] name:_Quinn, Olivia_>,
#   <Person id:4126525[http] name:_Redfern, Paul_>,
#   <Person id:5536411[http] name:_Redshaw, Jason_>,
#   <Person id:6805917[http] name:_Register, Eddie_>,
#   <Person id:6377106[http] name:_Sacco, Anthony J_>,
#   <Person id:7441016[http] name:_Santos, Bernardo_>,
#   <Person id:7477011[http] name:_Satalov, Andrei_>,
#   <Person id:6078944[http] name:_Simon, Dave_>,
#   <Person id:8606683[http] name:_Soffe, David_>,
#   <Person id:8000867[http] name:_Storey, Ryan_>,
#   <Person id:6836109[http] name:_Sullivan, Connor_>,
#   <Person id:4963833[http] name:_Talarowska, Camilla_>,
#   <Person id:4876392[http] name:_Thornton, Mitchell_>,
#   <Person id:6954178[http] name:_Trotter, Dan_>,
#   <Person id:7771733[http] name:_Tzanakou, Vassiliki_>,
#   <Person id:2917163[http] name:_Vij, Geeta_>,
#   <Person id:1234848[http] name:_Walters, Morgan_>,
#   <Person id:5594616[http] name:_Weir, Dean_>,
#   <Person id:6901826[http] name:_West, Tony Paul_>,
#   <Person id:5359722[http] name:_Wiget, Anick_>,
#   <Person id:6520637[http] name:_Zaruba, Miroslav_>],
#  u'casting department': [<Person id:8206770[http] name:_Earley, Ruth_>,
#   <Person id:7825350[http] name:_Millar, Abigail_>,
#   <Person id:7794848[http] name:_Penny, Adam_>,
#   <Person id:2130288[http] name:_Searby, Alice_>,
#   <Person id:0885021[http] name:_Vallely, Tannis_>,
#   <Person id:6309875[http] name:_Williams, Douglas_>,
#   <Person id:6008495[http] name:_Williams, Hannah Marie_>,
#   <Person id:6101113[http] name:_Wilson, Sarah_>],
#  'casting director': [<Person id:0918587[http] name:_Weir, Fiona_>],
#  'certificates': [u'Argentina:13',
#   u'Australia:M',
#   u'Austria:10',
#   u'Belgium:KT',
#   u'Brazil:12',
#   u'Canada:PG::(British Columbia)',
#   u'France:Tous publics',
#   u'Germany:6',
#   u'Hong Kong:IIA',
#   u'Indonesia:R',
#   u'Ireland:12A',
#   u'Japan:G',
#   u'Malaysia:P13',
#   u'Mexico:B',
#   u'Netherlands:9',
#   u'Philippines:PG-13',
#   u'Portugal:M/12',
#   u'Singapore:PG',
#   u'South Korea:12',
#   u'Sweden:11',
#   u'Switzerland:10',
#   u'Taiwan:PG-12',
#   u'Thailand:G',
#   u'UK:12A',
#   u'USA:PG-13::(certificate #50647)'],
#  'cinematographer': [<Person id:0003542[http] name:_Rousselot, Philippe_>],
#  'color info': [u'Color'],
#  u'costume department': [<Person id:3641350[http] name:_Allard, Ben_>,
#   <Person id:3291371[http] name:_Avery, Kathryn_>,
#   <Person id:4485938[http] name:_Bailey, Laura_>,
#   <Person id:7800237[http] name:_Barer, Frances E._>,
#   <Person id:3780179[http] name:_Barr, Mollie_>,
#   <Person id:6921813[http] name:_Beasley, Helen_>,
#   <Person id:5579174[http] name:_Bell, Jodie_>,
#   <Person id:8311539[http] name:_Best, Abigail_>,
#   <Person id:0134504[http] name:_Cantella, Christine L._>,
#   <Person id:6018880[http] name:_Cazmal, Daniela_>,
#   <Person id:7802100[http] name:_Costumer, Junior Crowd_>,
#   <Person id:4813817[http] name:_Cox, Alex_>,
#   <Person id:7361272[http] name:_Crean, Emma_>,
#   <Person id:5942929[http] name:_D'Agostino, Maria_>,
#   <Person id:6801069[http] name:_Danby, Hollie_>,
#   <Person id:7628661[http] name:_Duthie, Tom_>,
#   <Person id:6635188[http] name:_Ernst-Brown, Kristen_>,
#   <Person id:8505606[http] name:_Evans, William_>,
#   <Person id:6094471[http] name:_Fay, Sara_>,
#   <Person id:3806283[http] name:_Feulner, Simone_>,
#   <Person id:0277967[http] name:_Finlay, Charlotte_>,
#   <Person id:7134241[http] name:_Fitzsimons, Katie_>,
#   <Person id:4680663[http] name:_Gelpke, Jessie_>,
#   <Person id:5308591[http] name:_George, Louise_>,
#   <Person id:4185854[http] name:_Gibbs, Lily_>,
#   <Person id:6740824[http] name:_Gillies, Charles_>,
#   <Person id:6327316[http] name:_Goodall, Jessica_>,
#   <Person id:3388158[http] name:_Goyen, Perry_>,
#   <Person id:1096957[http] name:_Grace, Alex_>,
#   <Person id:7568198[http] name:_Hanet, Myra_>,
#   <Person id:2117710[http] name:_Hardaker, Claire_>,
#   <Person id:0371514[http] name:_Haynes, Monica_>,
#   <Person id:2664011[http] name:_Heath, Emma_>,
#   <Person id:8424304[http] name:_Heath, Lora_>,
#   <Person id:7472142[http] name:_Hendriks, Mariette_>,
#   <Person id:2753201[http] name:_Holder, Warren_>,
#   <Person id:1170519[http] name:_Hyams, Gary_>,
#   <Person id:2705863[http] name:_Ingham, Helen_>,
#   <Person id:4783697[http] name:_Ivans, Charlotte_>,
#   <Person id:6829558[http] name:_James, Sally_>,
#   <Person id:3610088[http] name:_Keyte, Sam_>,
#   <Person id:8424303[http] name:_Knight, Emily_>,
#   <Person id:2532171[http] name:_Lambe, Sophie_>,
#   <Person id:0492332[http] name:_Law, Jane_>,
#   <Person id:0492332[http] name:_Law, Jane_>,
#   <Person id:0497239[http] name:_Lee, Esther_>,
#   <Person id:5065797[http] name:_Logel, Diane_>,
#   <Person id:2865188[http] name:_MacKenzie, Susan_>,
#   <Person id:0541306[http] name:_Manasseh, Kay_>,
#   <Person id:2802884[http] name:_McGovern, William_>,
#   <Person id:5091164[http] name:_Miles, Stephanie_>,
#   <Person id:7888539[http] name:_Miller, Jenna_>,
#   <Person id:1238383[http] name:_Missaghian, Sanaz_>,
#   <Person id:2664262[http] name:_Von Schultze, Kathryn Mysko_>,
#   <Person id:5514432[http] name:_Nash, April_>,
#   <Person id:0627507[http] name:_Nevin, Shirley_>,
#   <Person id:7599336[http] name:_O'Driscoll, Alessio_>,
#   <Person id:8484162[http] name:_Ososki, Samuel_>,
#   <Person id:3068889[http] name:_Payne, Matt_>,
#   <Person id:6682319[http] name:_Phillips, Jessica_>,
#   <Person id:8706856[http] name:_Piatkowska, Julia_>,
#   <Person id:4445257[http] name:_Powell, Jennifer_>,
#   <Person id:8329687[http] name:_Prior, Sharona_>,
#   <Person id:3364819[http] name:_Rasmussen, Gemma_>,
#   <Person id:3070819[http] name:_Renouf, Laura_>,
#   <Person id:6235041[http] name:_Reynolds, Chloe_>,
#   <Person id:2041135[http] name:_Roche-Gordon, Christof_>,
#   <Person id:6678257[http] name:_Roelfs, Eva_>,
#   <Person id:6876056[http] name:_Scott, Kimberley_>,
#   <Person id:6033936[http] name:_Sheehy, Katie_>,
#   <Person id:1722241[http] name:_Smith, Marcia_>,
#   <Person id:4088337[http] name:_Sutherland, Robert James_>,
#   <Person id:3723119[http] name:_Traore, Sekou_>,
#   <Person id:2658228[http] name:_Usher, John_>,
#   <Person id:1935882[http] name:_Vaughan-Humphreys, Wyn_>,
#   <Person id:7866642[http] name:_Williams-Ellis, Isobel_>,
#   <Person id:3130686[http] name:_Wood, Lex_>,
#   <Person id:0949485[http] name:_Young, Dominic_>],
#  'costume designer': [<Person id:0041181[http] name:_Atwood, Colleen_>],
#  'countries': [u'UK', u'USA'],
#  'country codes': [u'gb', u'us'],
#  'cover url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjMxOTM1OTI4MV5BMl5BanBnXkFtZTgwODE5OTYxMDI@._V1._SX94_SY140_.jpg',
#  'director': [<Person id:0946734[http] name:_Yates, David_>],
#  u'distributors': [<Company id:0447557[http] name:_Cocinsa_>,
#   <Company id:0041079[http] name:_Karo Premiere_>,
#   <Company id:0484138[http] name:_NOS Audiovisuais_>,
#   <Company id:0236298[http] name:_Roadshow Entertainment_>,
#   <Company id:0093136[http] name:_Roadshow Films_>,
#   <Company id:0370614[http] name:_Tanweer Alliances_>,
#   <Company id:0135321[http] name:_Warner Bros. F.E._>,
#   <Company id:0077117[http] name:_Warner Bros._>,
#   <Company id:0176125[http] name:_Warner Bros._>,
#   <Company id:0139437[http] name:_Warner Bros._>,
#   <Company id:0189394[http] name:_Warner Bros._>,
#   <Company id:0030761[http] name:_Warner Bros._>,
#   <Company id:0014965[http] name:_Warner Bros._>,
#   <Company id:0023293[http] name:_Warner Bros._>,
#   <Company id:0045026[http] name:_Warner Bros._>,
#   <Company id:0033885[http] name:_Warner Bros._>,
#   <Company id:0127135[http] name:_Warner Bros._>,
#   <Company id:0026840[http] name:_Warner Bros._>,
#   <Company id:0488997[http] name:_KVH Media Group_>,
#   <Company id:0421459[http] name:_SF Film Finland_>],
#  'editor': [<Person id:0206504[http] name:_Day, Mark_>],
#  u'editorial department': [<Person id:1757927[http] name:_Adams, Matt_>,
#   <Person id:1043799[http] name:_Bate, Victoria_>,
#   <Person id:3490756[http] name:_Bryce, Stuart_>,
#   <Person id:1635935[http] name:_Burton, Mark_>,
#   <Person id:0126439[http] name:_Byrt, Hermione_>,
#   <Person id:4981611[http] name:_Chhatpar, Dhirendra_>,
#   <Person id:7072647[http] name:_Clough, Samuel_>,
#   <Person id:0187793[http] name:_Crickard, Paula_>,
#   <Person id:7281207[http] name:_Doherty, Sinéad_>,
#   <Person id:2700518[http] name:_Gokul, Meetal_>,
#   <Person id:3419132[http] name:_Gomez, Chema_>,
#   <Person id:3128997[http] name:_Hughes, Diarmuid_>,
#   <Person id:3292976[http] name:_Kemplen, Henry_>,
#   <Person id:8282664[http] name:_Kuehn, Karl_>,
#   <Person id:5092455[http] name:_Luseno, Lindah_>,
#   <Person id:4368494[http] name:_Marshall, Zach_>,
#   <Person id:4057459[http] name:_Mason, Emily_>,
#   <Person id:4441695[http] name:_McCulloch, Katie_>,
#   <Person id:2971554[http] name:_Newman, Jessica E._>,
#   <Person id:6551084[http] name:_Richards, Shaun_>,
#   <Person id:6118461[http] name:_Richardson, Daniel_>,
#   <Person id:2503906[http] name:_Robey, Myles_>,
#   <Person id:4312144[http] name:_Sevilla, Raul_>,
#   <Person id:3365744[http] name:_Twohey, Lee_>,
#   <Person id:6671642[http] name:_Vedant, Smeet_>,
#   <Person id:4654014[http] name:_Alvarez, Miriam_>,
#   <Person id:0451153[http] name:_Khan, Afnahn_>],
#  'full-size cover url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjMxOTM1OTI4MV5BMl5BanBnXkFtZTgwODE5OTYxMDI@.jpg',
#  'genres': [u'Adventure', u'Family', u'Fantasy'],
#  'kind': u'movie',
#  'language codes': [u'en', u'km'],
#  'languages': [u'English', u'Central Khmer'],
#  u'location management': [<Person id:3363318[http] name:_Bardsley, Peter_>,
#   <Person id:3363318[http] name:_Bardsley, Peter_>,
#   <Person id:7733191[http] name:_Battle, Mike_>,
#   <Person id:7733191[http] name:_Battle, Mike_>,
#   <Person id:8850964[http] name:_Denny-Northover, Tabitha_>,
#   <Person id:6442363[http] name:_Giles, Colin_>,
#   <Person id:7807609[http] name:_Green-Muid, Mitchell_>,
#   <Person id:7074701[http] name:_Jagdeo, Dolly_>,
#   <Person id:7309343[http] name:_Kidner, Gavin_>,
#   <Person id:4472243[http] name:_Lewis, Sarah Kate_>,
#   <Person id:6537120[http] name:_Loveday, Cazzie_>,
#   <Person id:7560530[http] name:_McCarthy, Hannah_>,
#   <Person id:0704001[http] name:_Quinn, Sue_>,
#   <Person id:3683115[http] name:_Turner, Georgette_>,
#   <Person id:2530340[http] name:_Whitty, Dan_>],
#  'long imdb canonical title': u'Fantastic Beasts and Where to Find Them (2016)',
#  'long imdb title': u'Fantastic Beasts and Where to Find Them (2016)',
#  'make up': [<Person id:5354094[http] name:_Barrass-Short, Jo_>,
#   <Person id:4572682[http] name:_Beech, Emmy_>,
#   <Person id:0121180[http] name:_Burger, Anita_>,
#   <Person id:8646014[http] name:_Caddy, Holly_>,
#   <Person id:6678764[http] name:_Connor, Emily Rose_>,
#   <Person id:3807130[http] name:_Couper, Tania_>,
#   <Person id:4117055[http] name:_Cox, Lauren Katie_>,
#   <Person id:4528084[http] name:_Coxon-Smith, Pollyanna_>,
#   <Person id:7541235[http] name:_Cracknell, Andrea_>,
#   <Person id:3801863[http] name:_Crouch, Sally_>,
#   <Person id:3801863[http] name:_Crouch, Sally_>,
#   <Person id:6198885[http] name:_da Silva, Laura Viana_>,
#   <Person id:4553151[http] name:_Garratt, Ellie_>,
#   <Person id:7181910[http] name:_Grove, Catherine_>,
#   <Person id:0358687[http] name:_Hammond, Fae_>,
#   <Person id:0413338[http] name:_Jackson, Carmel_>,
#   <Person id:8831648[http] name:_Karalic, Leila_>,
#   <Person id:8507609[http] name:_Kenton, Deb_>,
#   <Person id:2050147[http] name:_Knight, Sophia_>,
#   <Person id:0461548[http] name:_Knowles, Nicky_>,
#   <Person id:0654272[http] name:_Long, Suzi_>,
#   <Person id:1339434[http] name:_Malinowski, David_>,
#   <Person id:5351653[http] name:_Mangan, Colum_>,
#   <Person id:6219815[http] name:_Masters, Helen_>,
#   <Person id:0570579[http] name:_McInnes, Donald_>,
#   <Person id:4376698[http] name:_Mossman, Polly_>,
#   <Person id:5976959[http] name:_Phillips, Adam James_>,
#   <Person id:6546846[http] name:_Pyne, Chloë_>,
#   <Person id:1838915[http] name:_Redfern, Susie_>,
#   <Person id:1091063[http] name:_Rigby, Adrian_>,
#   <Person id:1737031[http] name:_Rouse, Alex_>,
#   <Person id:0791965[http] name:_Sheppard, Loulia_>,
#   <Person id:2190386[http] name:_Smith, Catherine Elizabeth_>,
#   <Person id:2842053[http] name:_Speke, Rachael_>,
#   <Person id:2842053[http] name:_Speke, Rachael_>,
#   <Person id:4655472[http] name:_Warrington, Victoria_>,
#   <Person id:1735627[http] name:_Weatherburn, Sarah_>,
#   <Person id:2095782[http] name:_Weston, Josh_>,
#   <Person id:1519796[http] name:_Young, Louise_>],
#  'miscellaneous companies': [<Company id:0002463[http] name:_2020 Casting_>,
#   <Company id:0582701[http] name:_Ann Koska Agency_>,
#   <Company id:0029274[http] name:_Audiolink Radio Communications_>,
#   <Company id:0590442[http] name:_BCD Entertainment Travel_>,
#   <Company id:0105319[http] name:_Casting Collective_>,
#   <Company id:0294826[http] name:_Codex_>,
#   <Company id:0128657[http] name:_De Lane Lea_>,
#   <Company id:0240771[http] name:_Fugitive Studios_>,
#   <Company id:0087225[http] name:_Helen Uffner Vintage Clothing_>,
#   <Company id:0216753[http] name:_HireWorks_>,
#   <Company id:0605417[http] name:_Howard Ray Film Transport Services_>,
#   <Company id:0373321[http] name:_Love High Speed_>,
#   <Company id:0115616[http] name:_Mad Dog Casting_>,
#   <Company id:0599304[http] name:_Matthews Street : Above The Line Catering_>,
#   <Company id:0334615[http] name:_Motion Picture Merchandise (MPM)_>,
#   <Company id:0385676[http] name:_Oh So Small Productions_>,
#   <Company id:0041930[http] name:_Panavision_>,
#   <Company id:0484515[http] name:_Rigging Services Direct_>,
#   <Company id:0389932[http] name:_Universal Extras_>,
#   <Company id:0284708[http] name:_Vision3_>,
#   <Company id:0293003[http] name:_WaterTower Music_>],
#  'miscellaneous crew': [<Person id:3475591[http] name:_Allan, Josh_>,
#   <Person id:6793791[http] name:_Arnold, Derek_>,
#   <Person id:7487490[http] name:_Aspin, Stephanie_>,
#   <Person id:7037639[http] name:_Asslanian, Tracy_>,
#   <Person id:1733686[http] name:_Baldwin, Fiona_>,
#   <Person id:7310816[http] name:_Ball, Sarah_>,
#   <Person id:7310816[http] name:_Ball, Sarah_>,
#   <Person id:6758674[http] name:_Barbour, Jordan_>,
#   <Person id:7305586[http] name:_Barratt, Paul_>,
#   <Person id:5397769[http] name:_Barron, Lewis_>,
#   <Person id:7328013[http] name:_Bentley-Jones, Oliver_>,
#   <Person id:3072337[http] name:_Berendt, Michael_>,
#   <Person id:7100653[http] name:_Berridge, Scott_>,
#   <Person id:6773110[http] name:_Blackaby, Leah_>,
#   <Person id:1318420[http] name:_Bohanna, Pierre_>,
#   <Person id:1471173[http] name:_Broderick, Matthew_>,
#   <Person id:2307000[http] name:_Broom, James_>,
#   <Person id:2852972[http] name:_Carmichael, Sam_>,
#   <Person id:8280347[http] name:_Carney, Faye_>,
#   <Person id:7190440[http] name:_Carter, Brett_>,
#   <Person id:6966630[http] name:_Caruso, Carmela_>,
#   <Person id:3666300[http] name:_Castro, Jussilinho_>,
#   <Person id:2762494[http] name:_Chalas, Aneta_>,
#   <Person id:0167299[http] name:_Clubb, Jim_>,
#   <Person id:3854782[http] name:_Coker, Rosie_>,
#   <Person id:7885288[http] name:_Cornell, Lara_>,
#   <Person id:5562352[http] name:_Craen, Hephzibah_>,
#   <Person id:3420469[http] name:_Croft, Ben_>,
#   <Person id:1458300[http] name:_Curtis, Matt_>,
#   <Person id:0218426[http] name:_Demetriou, Robin_>,
#   <Person id:7393393[http] name:_Dennis, Charlie_>,
#   <Person id:5359732[http] name:_Dent, Sam_>,
#   <Person id:3112777[http] name:_Devil, Jason_>,
#   <Person id:8264105[http] name:_Dixon, Samantha_>,
#   <Person id:0236927[http] name:_Drake, Jessica_>,
#   <Person id:2601401[http] name:_Edwards, Charles_>,
#   <Person id:7573358[http] name:_Etherington, Chris_>,
#   <Person id:8128330[http] name:_Excell, James_>,
#   <Person id:6465708[http] name:_Farsad, Riyonn_>,
#   <Person id:8084856[http] name:_Fullerton, Rachael_>,
#   <Person id:8097858[http] name:_Furr, Alexandrea_>,
#   <Person id:7573354[http] name:_Gettens, Leigh_>,
#   <Person id:6442363[http] name:_Giles, Colin_>,
#   <Person id:7177152[http] name:_Green, Melissa_>,
#   <Person id:4947111[http] name:_Guiver, Robin_>,
#   <Person id:4571226[http] name:_Hansson, Nicklas_>,
#   <Person id:7445982[http] name:_Havill, Robert_>,
#   <Person id:2475051[http] name:_Hazell, Emma_>,
#   <Person id:4440555[http] name:_Hingst, Katharina_>,
#   <Person id:2301377[http] name:_Hook, Natasha_>,
#   <Person id:0394017[http] name:_Hope, Luke_>,
#   <Person id:6167617[http] name:_Hoque, Nasrin_>,
#   <Person id:3092690[http] name:_Huet, Marianne_>,
#   <Person id:5972134[http] name:_Hussain, Moin_>,
#   <Person id:3072025[http] name:_Irvine, Amy_>,
#   <Person id:5065810[http] name:_Jamieson, Craig_>,
#   <Person id:5065810[http] name:_Jamieson, Craig_>,
#   <Person id:7887724[http] name:_Kalfuntzos, Lampros_>,
#   <Person id:1447251[http] name:_Karzen, Marc_>,
#   <Person id:2262417[http] name:_Koska, Ann_>,
#   <Person id:6972706[http] name:_Leaney, Jane_>,
#   <Person id:6968647[http] name:_Lewin, Richard Anthony_>,
#   <Person id:4488888[http] name:_Mackey, Norina_>,
#   <Person id:1153727[http] name:_Mann, Stacy_>,
#   <Person id:0543827[http] name:_Mansfield, Sharon_>,
#   <Person id:7084107[http] name:_McCartney, Liam_>,
#   <Person id:0567200[http] name:_McCullough, Jill_>,
#   <Person id:0570032[http] name:_McGregor, Wayne_>,
#   <Person id:3351236[http] name:_McLaren, Fiona May_>,
#   <Person id:1573695[http] name:_McNeil, Alastair_>,
#   <Person id:6079759[http] name:_Mear, Brian_>,
#   <Person id:7432808[http] name:_Miles, Charlotte Amelia_>,
#   <Person id:6966911[http] name:_Miles, Georgina_>,
#   <Person id:7429703[http] name:_Mulligan, Sally_>,
#   <Person id:0633235[http] name:_Nixon, Gary_>,
#   <Person id:5404270[http] name:_Nixon, Josh_>,
#   <Person id:4149757[http] name:_Orpheus, David_>,
#   <Person id:5715405[http] name:_Packham, Tim_>,
#   <Person id:3852540[http] name:_Palmer, Martine_>,
#   <Person id:3852540[http] name:_Palmer, Martine_>,
#   <Person id:2008431[http] name:_Pariente, Miguel_>,
#   <Person id:4188775[http] name:_Parry, Andy_>,
#   <Person id:1246512[http] name:_Payton, James_>,
#   <Person id:2125350[http] name:_Pearce, Ben_>,
#   <Person id:7095998[http] name:_Peters, Jan_>,
#   <Person id:8412228[http] name:_Pretlove, Lee_>,
#   <Person id:5051905[http] name:_Pritchard, Hannah_>,
#   <Person id:7603353[http] name:_Ray, Tom_>,
#   <Person id:7742077[http] name:_Reece, Laura_>,
#   <Person id:3608707[http] name:_Rothwell, Ben_>,
#   <Person id:5666211[http] name:_Rothwell, Victoria_>,
#   <Person id:1348812[http] name:_Rowden, Angela_>,
#   <Person id:6273242[http] name:_Serpini, Lucia_>,
#   <Person id:4002599[http] name:_Sewell, Faye_>,
#   <Person id:2189121[http] name:_Silva, Rob_>,
#   <Person id:6891215[http] name:_Smith, Kaitlyn_>,
#   <Person id:3633063[http] name:_Stafford-Clark, David_>,
#   <Person id:4719036[http] name:_Steele, Brian_>,
#   <Person id:8312708[http] name:_Street, Matthews_>,
#   <Person id:4873015[http] name:_Taylor, Ewan_>,
#   <Person id:1623201[http] name:_Tidy, Katharine_>,
#   <Person id:6147103[http] name:_Tilbury, James_>,
#   <Person id:6253030[http] name:_Unwin, Sarah_>,
#   <Person id:5030129[http] name:_Vannucci, Gianpiero_>,
#   <Person id:4496356[http] name:_Vaughan, Charlie_>,
#   <Person id:3932629[http] name:_von Schlippe, Zuzana_>,
#   <Person id:7408361[http] name:_Ward, Andrew_>,
#   <Person id:2961855[http] name:_Ware, Sean_>,
#   <Person id:6904866[http] name:_Wayre, Jonathan_>,
#   <Person id:2641022[http] name:_Whiting, Rebecca_>,
#   <Person id:5139301[http] name:_Williams, Luke Kimble_>,
#   <Person id:2711324[http] name:_Wilson, Chris_>,
#   <Person id:7680731[http] name:_Wilton, Tom_>,
#   <Person id:5554758[http] name:_Winter, Jo_>,
#   <Person id:0936534[http] name:_Wishart, Winnie_>,
#   <Person id:0941492[http] name:_Worley, Anna_>,
#   <Person id:2451951[http] name:_Wren, Camilla_>,
#   <Person id:7701629[http] name:_Young, Phoebe_>,
#   <Person id:1834800[http] name:_Bloom, Kiri_>,
#   <Person id:2692870[http] name:_Ellinas, Andrew_>,
#   <Person id:5292910[http] name:_Gresley, Annabelle Le_>,
#   <Person id:2730610[http] name:_Martinez, Michael_>,
#   <Person id:0780550[http] name:_Sealey, Mark_>,
#   <Person id:3603701[http] name:_Shah, Arti_>],
#  'mpaa': u'Rated PG-13 for some fantasy action violence',
#  u'music department': [<Person id:0030981[http] name:_Anthony, Pete_>,
#   <Person id:0030981[http] name:_Anthony, Pete_>,
#   <Person id:4643931[http] name:_Aschalew, Jon_>,
#   <Person id:0040873[http] name:_Atmajian, Jeff_>,
#   <Person id:5139120[http] name:_Bahnmiller, Michael_>,
#   <Person id:2997073[http] name:_Barrett, John_>,
#   <Person id:0077444[http] name:_Berrow, Mark_>,
#   <Person id:1020391[http] name:_Bolt, Rachel_>,
#   <Person id:2147161[http] name:_Bowes, Thomas_>,
#   <Person id:0102083[http] name:_Boyer, Peter_>,
#   <Person id:6794942[http] name:_Brown, Daniel A._>,
#   <Person id:6250736[http] name:_Choi, Jina B._>,
#   <Person id:0167838[http] name:_Cobbin, Peter_>,
#   <Person id:0167838[http] name:_Cobbin, Peter_>,
#   <Person id:0185483[http] name:_Cozens, Chris_>,
#   <Person id:2166117[http] name:_Egan, Chris_>,
#   <Person id:0254514[http] name:_Elliott, Karen_>,
#   <Person id:7419781[http] name:_Flynn, Luke_>,
#   <Person id:0334204[http] name:_Graham, Mark_>,
# ...
#   <Person id:8531979[http] name:_Leygnac, Hugo_>,
#   <Person id:8531979[http] name:_Leygnac, Hugo_>,
#   <Person id:5051539[http] name:_Licinio, Aulo_>,
#   <Person id:4540675[http] name:_Lickiss, Seth_>,
#   <Person id:7994034[http] name:_Tønnesen, Tord Liljedahl_>,
#   <Person id:3646318[http] name:_Lim, Edy Susanto_>,
#   <Person id:5380532[http] name:_Lim, Wayne_>,
#   <Person id:4808188[http] name:_Ling, Cedric_>,
#   <Person id:6380800[http] name:_Litz, Rachel_>,
#   <Person id:4572688[http] name:_Liu, Shenyan_>,
#   <Person id:6187672[http] name:_Livingstone, Andrew_>,
#   <Person id:4268462[http] name:_Llave, Brendan_>,
#   <Person id:4379635[http] name:_Lmouaci, Wassila_>,
#   <Person id:6565447[http] name:_Lobato, Caroline_>,
#   <Person id:4893708[http] name:_Lobban, Nick_>,
#   <Person id:1639901[http] name:_Loch, Benjamin_>,
#   <Person id:3837392[http] name:_Lodomez, Jeremie_>,
#   <Person id:3032067[http] name:_Long, James_>,
#   <Person id:5351811[http] name:_Long, Joe_>,
#   <Person id:7898506[http] name:_Lopatin, Benjamin_>,
#   <Person id:1105748[http] name:_Lord, François_>,
#   <Person id:5923554[http] name:_Lorenzo, Michael_>,
#   <Person id:1800473[http] name:_LoRusso, Alexandra_>,
#   <Person id:8148934[http] name:_Loucas, Mike_>,
#   <Person id:2939712[http] name:_Lovell, Steven_>,
#   <Person id:4755763[http] name:_Loyer, Valerie_>,
#   <Person id:0524275[http] name:_Lucas, Sam_>,
#   <Person id:7912414[http] name:_Lundy, Julie_>,
#   <Person id:1647244[http] name:_Lunney, Chris_>,
#   <Person id:2601332[http] name:_Luong, Lucy_>,
#   <Person id:1914658[http] name:_Luongo, Fabio_>,
#   <Person id:6521500[http] name:_Luttman, Kevin_>,
#   <Person id:3270850[http] name:_Léger, Mickaël_>,
#   <Person id:6768618[http] name:_Lévêque, Bruno_>,
#   <Person id:0530895[http] name:_Ma, Susan_>,
#   <Person id:3184322[http] name:_MacDonald, Sarah_>,
#   <Person id:5924448[http] name:_Macfadyen, Laura_>,
#   <Person id:7259914[http] name:_Mack, Melanie_>,
#   <Person id:7454520[http] name:_Madala, Ajay_>,
#   <Person id:3947545[http] name:_Maddison, Garry_>,
#   <Person id:4224844[http] name:_Madeline, Renaud_>,
#   <Person id:6006172[http] name:_Maggio, Luciano_>,
#   <Person id:8297647[http] name:_Magri, Andrew_>,
#   <Person id:6451106[http] name:_Mahajan, Gokul_>,
#   <Person id:4683902[http] name:_Maharaj, Ethan_>,
#   <Person id:7554756[http] name:_Mai, Khoi_>,
#   <Person id:6382769[http] name:_Mainville, Isabelle_>,
#   <Person id:3995153[http] name:_Majors, Carson_>,
#   <Person id:3860367[http] name:_Majors, Yael_>,
#   <Person id:6221168[http] name:_Mak, Vincent Febriyanto_>,
#   <Person id:4393221[http] name:_Makhija, Suraj_>,
#   <Person id:3467458[http] name:_Maldonado, David_>,
#   <Person id:7186912[http] name:_Malherbe, Arnaud_>,
#   <Person id:8598277[http] name:_Malott, Brad_>,
#   <Person id:5520183[http] name:_Manavi, Amir_>,
#   <Person id:4988302[http] name:_Mangion, Dean_>,
#   <Person id:8677386[http] name:_Mangipudi, Srikanth_>,
#   <Person id:7522018[http] name:_Manning, Ashley_>,
#   <Person id:5570831[http] name:_Mantero, Manolo_>,
#   <Person id:7696810[http] name:_Garzon, Fernando Mantilla_>,
#   <Person id:7696810[http] name:_Garzon, Fernando Mantilla_>,
#   <Person id:1114640[http] name:_Manz, Christian_>,
#   <Person id:6943445[http] name:_Marchand, Jean-Philippe_>,
#   <Person id:6357213[http] name:_Marcotte, Marilyn_>,
#   <Person id:8484973[http] name:_Marks, Julie-Ann_>,
#   <Person id:8590054[http] name:_Marsicovetere, Gianfranco_>,
#   <Person id:3368097[http] name:_Martin, Brandon_>,
#   <Person id:7289212[http] name:_Martin, Dominic_>,
#   <Person id:4374437[http] name:_Martin, Edward_>,
#   <Person id:4405345[http] name:_Martinez, Fran_>,
#   <Person id:7317707[http] name:_Mason, Ashley_>,
#   <Person id:3824794[http] name:_Mason, Dan_>,
#   <Person id:2069697[http] name:_Massar, Rudy_>,
#   <Person id:5617461[http] name:_Masse, Maxime Olivier_>,
#   <Person id:7695834[http] name:_Massingham, Laura_>,
#   <Person id:1836428[http] name:_Masson, Mark_>,
#   <Person id:7451209[http] name:_Mateo, Nathan_>,
#   <Person id:2055038[http] name:_Matsumura, Tomoka_>,
#   <Person id:6268880[http] name:_Crowe, Matthew_>,
#   <Person id:5535479[http] name:_Maund, Daniel_>,
#   <Person id:3271740[http] name:_Mauritzen, Michael Hall_>,
#   <Person id:4432835[http] name:_Guire, Eric Mc_>,
#   <Person id:7907046[http] name:_McBain, Colin_>,
#   <Person id:8044773[http] name:_McBride, Graham_>,
#   <Person id:4918931[http] name:_McClain, Mb X._>,
#   <Person id:7802575[http] name:_McCormack-Douglas, Mark_>,
#   <Person id:3044160[http] name:_McEvoy, Niall_>,
#   <Person id:4638932[http] name:_McGonigle, Owen_>,
#   <Person id:5926133[http] name:_McGowan, Brooke_>,
#   <Person id:3558615[http] name:_McGuire, Declan_>,
#   <Person id:3566772[http] name:_McInnes, Scott_>,
#   <Person id:3951758[http] name:_McKay, David_>,
#   <Person id:5432007[http] name:_McKeating, Michelle_>,
#   <Person id:3966120[http] name:_McLaughlin, Chris_>,
#   <Person id:2381449[http] name:_McLeod, Steve_>,
#   <Person id:3792478[http] name:_McMullan, Donal_>,
#   <Person id:7806176[http] name:_Meakins, Liam_>,
#   <Person id:7104500[http] name:_Medcraft, Zoe_>,
#   <Person id:4790531[http] name:_Meena, Himanshu_>,
#   <Person id:7206810[http] name:_Meevasana, Wanamas_>,
#   <Person id:1634061[http] name:_Mehmet, Gurel_>,
#   <Person id:3134412[http] name:_Melancon, Philip_>,
#   <Person id:6967094[http] name:_Melo, Hugo_>,
#   <Person id:7365707[http] name:_Melville, Alexander_>,
#   <Person id:3192103[http] name:_Mendiburu, Mariano_>,
#   <Person id:3479159[http] name:_Jr., Carlos Mendoza_>,
#   <Person id:5107540[http] name:_Menoudakis, Catherine_>,
#   <Person id:3420145[http] name:_Menyhei, Szabolcs_>,
#   <Person id:0579992[http] name:_Menzies, Ian_>,
#   <Person id:4180134[http] name:_Meo, Massimo_>,
#   <Person id:4399305[http] name:_Mercier, Simon_>,
#   <Person id:7152302[http] name:_Methven, Josh_>,
#   <Person id:4446677[http] name:_Metz, Christophe_>,
#   <Person id:4446677[http] name:_Metz, Christophe_>,
#   <Person id:2348479[http] name:_Meza, Margarita_>,
#   <Person id:5089267[http] name:_Michael, Jared_>,
#   <Person id:5374852[http] name:_Midelfort, Jarl_>,
#   <Person id:1210322[http] name:_Migodzinska, Joanna_>,
#   <Person id:1210322[http] name:_Migodzinska, Joanna_>,
#   <Person id:4472341[http] name:_Palombo, Alejandro Miranda_>,
#   <Person id:4707083[http] name:_Mistry, Harsh_>,
#   <Person id:4053949[http] name:_Mitchell, Scott_>,
#   <Person id:7498465[http] name:_Mlahaili, Akmal_>,
#   <Person id:3878892[http] name:_Moffat, Emma_>,
#   <Person id:3076026[http] name:_Mohamed, Effandi_>,
#   <Person id:3522070[http] name:_Mohasseb, Farhad_>,
#   <Person id:8624037[http] name:_Moktar, Benjamin_>,
#   <Person id:5087157[http] name:_Moldavski, Kobi_>,
#   <Person id:6661187[http] name:_Moltisanti, Damiano_>,
#   <Person id:1677382[http] name:_Moncur, Steve_>,
#   <Person id:7895595[http] name:_Mongeau, Philippe_>,
#   <Person id:5883164[http] name:_Montague, Blanaid_>,
#   <Person id:7795463[http] name:_Montambault, Hugo_>,
#   <Person id:3131652[http] name:_Montefusco, John_>,
#   <Person id:2930276[http] name:_Montesano, Chris_>,
#   <Person id:8157506[http] name:_Montminy-Brodeur, Samuel_>,
#   <Person id:2984157[http] name:_Moody, Daniel_>,
#   <Person id:2886658[http] name:_Moor, Steven_>,
#   <Person id:0603441[http] name:_Moreau, Sébastien_>,
#   <Person id:6535268[http] name:_Moreira, Maxime_>,
#   <Person id:6505572[http] name:_Morin, Emmanuelle_>,
#   <Person id:1288034[http] name:_Morissette, Jean-Francois_>,
#   <Person id:1266585[http] name:_Morley, Andrew_>,
#   <Person id:8355745[http] name:_Morris, Claire_>,
#   <Person id:5763468[http] name:_Mortelecque, Bastien_>,
#   <Person id:5718796[http] name:_Mucino, Sergio_>,
#   <Person id:5289029[http] name:_Muller, Bastien_>,
#   <Person id:4890438[http] name:_Mulligan, Andy_>,
#   <Person id:4580465[http] name:_Munns, Chris_>,
#   <Person id:5105202[http] name:_Munro, Stuart_>,
#   <Person id:2524928[http] name:_Munzar, Tomas_>,
#   <Person id:3664326[http] name:_Murcho, Gautama_>,
#   <Person id:6904561[http] name:_Murray, Melanie_>,
#   <Person id:8630807[http] name:_Mursch, Gabriela_>,
#   <Person id:8334275[http] name:_Muruganantham_>,
#   <Person id:8695987[http] name:_Murughendra, Prakash_>,
#   <Person id:4439305[http] name:_Musselman, Scott_>,
#   <Person id:7702345[http] name:_Muthukumar, Jayaraj_>,
#   <Person id:4178679[http] name:_Muzzolini, Monica_>,
#   <Person id:5491413[http] name:_Muñoz, Javier_>,
#   <Person id:7877515[http] name:_Nalewajek, Natascha_>,
#   <Person id:2135543[http] name:_Nardini, Alessandro_>,
#   <Person id:5605290[http] name:_Narwani, Amit_>,
#   <Person id:8292085[http] name:_Nasir, Zeeshan_>,
#   <Person id:8591626[http] name:_Nath, Sudipto_>,
#   <Person id:0623408[http] name:_Naze, Stephane_>,
#   <Person id:1806960[http] name:_Nelhams, Stuart_>,
#   <Person id:4835923[http] name:_Nelson, Paul_>,
#   <Person id:8289491[http] name:_Nemeth, Maxwell_>,
#   <Person id:7218116[http] name:_Neri, Alessandro_>,
#   <Person id:4662754[http] name:_Nerurkar, Avadhut_>,
#   <Person id:5108557[http] name:_Ness, Sebastian_>,
#   <Person id:1276823[http] name:_Nettleton, Shannon_>,
#   <Person id:5878255[http] name:_Neveu, Sarah_>,
#   <Person id:1893610[http] name:_Newbauer, Pete C._>,
#   <Person id:4161688[http] name:_Newbold, Stephen_>,
#   <Person id:1001555[http] name:_Newby, Helen_>,
#   <Person id:4514600[http] name:_Newman, Nicolette_>,
#   <Person id:4374581[http] name:_Nguyen, Giang T._>,
#   <Person id:2435877[http] name:_Nicholl, James_>,
#   <Person id:1917624[http] name:_Noon, James P._>,
#   <Person id:0635466[http] name:_Norman, Clare_>,
#   <Person id:1315375[http] name:_Norrie, Mark_>,
#   <Person id:5967538[http] name:_Nouveau, Sylvain_>,
#   <Person id:2047115[http] name:_O'Brien, Barry_>,
#   <Person id:1979121[http] name:_O'Lone, John_>,
#   <Person id:4593010[http] name:_O'Shaughnessy, Daniel_>,
#   <Person id:8052625[http] name:_O'Sullivan, Matthew_>,
#   <Person id:6517644[http] name:_Ogale, Alok_>,
#   <Person id:0645521[http] name:_Okano, Hideki_>,
#   <Person id:8458294[http] name:_Olsauskaite, Adele_>,
#   <Person id:2043607[http] name:_Ong, Nguon Vissal_>,
#   <Person id:2191835[http] name:_Opgenhaffen, Jonathan_>,
#   <Person id:2443030[http] name:_Orliani, Michelangelo Neri_>,
#   <Person id:4927985[http] name:_Oseguera, Raphael_>,
#   <Person id:4500997[http] name:_Ouilhet, Eduardo Parra_>,
#   <Person id:1310932[http] name:_Ozerski, Matthew_>,
#   <Person id:1280701[http] name:_Pacaud, Christophe_>,
#   <Person id:7925156[http] name:_Palin, Béatrice_>,
#   <Person id:4487263[http] name:_Pan, Guo Kun_>,
#   <Person id:4416179[http] name:_Panagiotopoulos, Konstantinos_>,
#   <Person id:4667948[http] name:_Pandey, Bhavesh_>,
#   <Person id:4301894[http] name:_Pandey, Shailendra Kumar_>,
#   <Person id:2252167[http] name:_Panton, Peter_>,
#   <Person id:8587753[http] name:_Papatens-Rochon, Niomie_>,
#   <Person id:2981042[http] name:_Papp, Nikolett_>,
#   <Person id:8458909[http] name:_Paquet, Camille_>,
#   <Person id:0660763[http] name:_Paquin, Jonathan_>,
#   <Person id:8175061[http] name:_Park, Catherine_>,
#   <Person id:5360178[http] name:_Park, Sehwi_>,
#   <Person id:1889013[http] name:_Parks, Chris_>,
#   <Person id:1026930[http] name:_Parry, Aaron_>,
#   <Person id:0664330[http] name:_Pascarelli, Eric_>,
#   <Person id:0664330[http] name:_Pascarelli, Eric_>,
#   <Person id:5719214[http] name:_Passarella, Dana_>,
#   <Person id:4814698[http] name:_Bartoli, Diego Pastor_>,
#   <Person id:2324198[http] name:_Patapoff, Sydney_>,
#   <Person id:7271109[http] name:_Patel, Harshna_>,
#   <Person id:5192081[http] name:_Patel, Nikul_>,
#   <Person id:7661107[http] name:_Patterson, Jeremy_>,
#   <Person id:2915003[http] name:_Pavanrajesh, Uppu_>,
#   <Person id:7114218[http] name:_Pearce, Gareth_>,
#   <Person id:8573240[http] name:_Pearce, Jessica_>,
#   <Person id:7909076[http] name:_Pedde, Garrett_>,
#   <Person id:1391075[http] name:_Pedder, Geoff_>,
#   <Person id:1925469[http] name:_Pegg, Tom_>,
#   <Person id:4339636[http] name:_Pelc, Daniel_>,
#   <Person id:4422594[http] name:_Pellard, Laurie_>,
#   <Person id:2245587[http] name:_Pelletier, Martin_>,
#   <Person id:2989252[http] name:_Perendija, Marko_>,
#   <Person id:2765357[http] name:_Perez, Angelica_>,
#   <Person id:7856382[http] name:_Perez, Juan Sebastian_>,
#   <Person id:7460792[http] name:_Perreault, Gabrielle_>,
#   <Person id:3560176[http] name:_Perrin, Matt_>,
#   <Person id:1844368[http] name:_Perry, Richard_>,
#   <Person id:6267984[http] name:_Ashford, Pete_>,
#   <Person id:4744773[http] name:_Petkov, Dennis_>,
#   <Person id:6674054[http] name:_Petrie, Leela_>,
#   <Person id:6634405[http] name:_Petrov, Viktor_>,
#   <Person id:8651703[http] name:_Pfister, Carlos_>,
#   <Person id:2111490[http] name:_Pham, Chi_>,
#   <Person id:3133778[http] name:_Phaneuf, Mathieu_>,
#   <Person id:6524352[http] name:_Philippon, Maxime_>,
#   <Person id:2669186[http] name:_Phillips, Kate_>,
#   <Person id:5861155[http] name:_Phonasa, Phets_>,
#   <Person id:5729193[http] name:_Piacente, Brittany_>,
#   <Person id:3390859[http] name:_Piché, Dominic_>,
#   <Person id:8278804[http] name:_Pickup, Danielle_>,
#   <Person id:8278804[http] name:_Pickup, Danielle_>,
#   <Person id:2991507[http] name:_Pike, Ezra_>,
#   <Person id:3136520[http] name:_Pinnoju, Praveena_>,
#   <Person id:1004848[http] name:_Place, Fred_>,
#   <Person id:2693439[http] name:_Plewes, Britton_>,
#   <Person id:8498930[http] name:_Poirier, Sabrina_>,
#   <Person id:5617587[http] name:_Poirier, Samuel_>,
#   <Person id:4755694[http] name:_Poissant, Patrice_>,
#   <Person id:7160385[http] name:_Polke, Yash_>,
#   <Person id:2083061[http] name:_Ponti, Pietro_>,
#   <Person id:1994769[http] name:_Ponton, Eric_>,
#   <Person id:2001812[http] name:_Popovic, Vladimir_>,
#   <Person id:1578630[http] name:_Porter, Travis_>,
#   <Person id:1433758[http] name:_Potter, Tim_>,
#   <Person id:3169827[http] name:_St-Laurent, Etienne Poulin_>,
#   <Person id:3419701[http] name:_Poulin, Guillaume_>,
#   <Person id:5627521[http] name:_Poulin, Marc-Andre_>,
#   <Person id:1619387[http] name:_Pounds-Cornish, Tim_>,
#   <Person id:7172755[http] name:_Pownall, Becky_>,
#   <Person id:4729453[http] name:_Prapas, Akie_>,
#   <Person id:4336342[http] name:_Prasanth, Kukal_>,
#   <Person id:4090835[http] name:_Preissner, Jeremy_>,
#   <Person id:4859199[http] name:_Presti, Matthieu_>,
#   <Person id:2521063[http] name:_Pring, Richard_>,
#   <Person id:6189415[http] name:_Priya, Ankit_>,
#   <Person id:7663838[http] name:_Probert, Stewart_>,
#   <Person id:5973989[http] name:_Proctor, Ted_>,
#   <Person id:7405818[http] name:_Providence, Aaron_>,
#   <Person id:0699286[http] name:_Prusak, Derek N._>,
#   <Person id:3521080[http] name:_Prévost, Jeanne-Élise_>,
#   <Person id:2262492[http] name:_Puchta, Christopher_>,
#   <Person id:4751852[http] name:_Puech, Simon-Pierre_>,
#   <Person id:4755798[http] name:_Pulvirenti, Giorgia_>,
#   <Person id:8663271[http] name:_Pyper, James_>,
#   <Person id:1280880[http] name:_Pélissier, Martin_>,
#   <Person id:7208278[http] name:_Quattrociocchi, Adam_>,
#   <Person id:4613228[http] name:_Quijada, Carlos_>,
#   <Person id:6612175[http] name:_Raad, Michel_>,
#   <Person id:4104228[http] name:_Radinkovic, Marko_>,
#   <Person id:0706688[http] name:_Rahhali, Nordin_>,
#   <Person id:8337250[http] name:_Rajarajan, Sathya_>,
#   <Person id:8672534[http] name:_Rajat, Bhattacharjee_>,
#   <Person id:8476388[http] name:_Rakesh_Mukherjee_>,
#   <Person id:8564344[http] name:_Ramani, Keerthana_>,
#   <Person id:8044436[http] name:_Ramirez, Adrian_>,
#   <Person id:6429801[http] name:_Ramsey, Austin_>,
#   <Person id:5759747[http] name:_Ramsey, Ryan_>,
#   <Person id:7569309[http] name:_Ranatunga, Subodhana_>,
#   <Person id:2892464[http] name:_Rapley, Karl_>,
#   <Person id:7267006[http] name:_Ratajczak, David_>,
#   <Person id:2599192[http] name:_Rathod, Sagar_>,
#   <Person id:5500816[http] name:_Ray, Kisholay_>,
#   <Person id:6553571[http] name:_Raza, Aamir_>,
#   <Person id:8124138[http] name:_Rebello, Diego_>,
#   <Person id:1324047[http] name:_Reeb, Ryan_>,
#   ...],
#  'votes': 205785,
#  'writer': [<Person id:0746830[http] name:_Rowling, J.K._>],
#  'year': 2016}

# %% [markdown]
# as for the titles, we considered two ways:
# 1. Use english titles
# 2. Use titles where it is produced/in what language (but not comparable among, countries have different grammar systems.)

# %% [markdown]
# **IMDb select attributes**

# %%
favorite_movie_imdb.keys()
# Out:
# [u'music department',
#  'sound crew',
#  'camera and electrical department',
#  u'distributors',
#  'rating',
#  'runtimes',
#  'costume designer',
#  'make up',
#  'year',
#  'production design',
#  'miscellaneous crew',
#  'color info',
#  u'casting department',
#  'languages',
#  'votes',
#  'producer',
#  'title',
#  'mpaa',
#  'assistant director',
#  'writer',
#  'casting director',
#  'visual effects',
#  'production manager',
#  'set decoration',
#  'editor',
#  'certificates',
#  u'costume department',
#  'country codes',
#  'language codes',
#  'cover url',
#  u'special effects department',
#  'special effects companies',
#  'sound mix',
#  u'location management',
#  'genres',
#  'director',
#  'stunt performer',
#  'miscellaneous companies',
#  'cinematographer',
#  'art direction',
#  'akas',
#  'aspect ratio',
#  u'production companies',
#  'kind',
#  u'art department',
#  'countries',
#  u'transportation department',
#  'plot outline',
#  'plot',
#  'cast',
#  u'animation department',
#  'original music',
#  u'editorial department',
#  'canonical title',
#  'long imdb title',
#  'long imdb canonical title',
#  'smart canonical title',
#  'smart long imdb canonical title',
#  'full-size cover url']

# %%
#a list to helpful attributes from imdb
attr_imdb =  favorite_movie_imdb.keys()
attr_keep_imdb = ['rating','runtimes','year','color info','languages','votes','title','mpaa','certificates','country codes',
                 'language codes','cover url','sound mix','genres','director','aspect ratio','production companies'
                 ,'kind','countries','plot outline','plot','original music','canonical title','long imdb title','long imdb canonical title',
                 'smart canonical title','smart long imdb canonical title','full-size cover url']

# %% [markdown]
# **Transform into dataframe**

# %%
#tmdb
df1 = pd.DataFrame([favorite_movie_tmdb])
df1['imdb_id'] = df1['imdb_id'].apply(lambda x: x[2:])
df1
# Out:
#    adult                     backdrop_path  \
# 0  False  /kMzU4PkXcKcDMngCxXji0BbVXsu.jpg
#
#                                belongs_to_collection     budget  \
# 0  {u'backdrop_path': u'/jc1Sh8U6dvWv9rHaRl8aosTA...  180000000
#
#                                               genres  \
# 0  [{u'id': 12, u'name': u'Adventure'}, {u'id': 2...
#
#                           homepage      id  imdb_id original_language  \
# 0  http://www.fantasticbeasts.com/  259316  3183660                en
#
#                             original_title    ...     release_date    revenue  \
# 0  Fantastic Beasts and Where to Find Them    ...       2016-11-16  809342332
#
#   runtime                              spoken_languages    status  \
# 0     133  [{u'iso_639_1': u'en', u'name': u'English'}]  Released
#
#                                 tagline  \
# 0  From J.K. Rowling's wizarding world.
#
#                                      title  video vote_average vote_count
# 0  Fantastic Beasts and Where to Find Them  False          7.0       3122
#
# [1 rows x 25 columns]

# %%
#convert imdb movie object to dictionary
def imdb_to_dict(movie):
    
    new_dict = {}
    new_dict['imdb_id'] = movie.getID()
    
    for ele in attr_keep_imdb:
        
        #check type list and convert every element to str
        if type(movie[ele]) == list:
            value = [str(i) for i in movie[ele]]
            new_dict[ele] = value
            
        new_dict[ele] = movie[ele]
    
    df = pd.DataFrame([new_dict])
    return df

# %%
df2 = imdb_to_dict(favorite_movie_imdb)
df2
# Out:
#   aspect ratio                          canonical title  \
# 0     1.85 : 1  Fantastic Beasts and Where to Find Them
#
#                                         certificates color info  countries  \
# 0  [Argentina:13, Australia:M, Austria:10, Belgiu...    [Color]  [UK, USA]
#
#   country codes                                          cover url  \
# 0      [gb, us]  https://images-na.ssl-images-amazon.com/images...
#
#         director                                full-size cover url  \
# 0  [David Yates]  https://images-na.ssl-images-amazon.com/images...
#
#                          genres  ...   \
# 0  [Adventure, Family, Fantasy]  ...
#
#                                         plot outline  \
# 0  The adventures of writer Newt Scamander in New...
#
#            production companies rating runtimes  \
# 0  [Heyday Films, Warner Bros.]    7.5    [133]
#
#                      smart canonical title  \
# 0  Fantastic Beasts and Where to Find Them
#
#                   smart long imdb canonical title  \
# 0  Fantastic Beasts and Where to Find Them (2016)
#
#                                sound mix  \
# 0  [Datasat, Dolby Digital, Dolby Atmos]
#
#                                      title   votes  year
# 0  Fantastic Beasts and Where to Find Them  205785  2016
#
# [1 rows x 29 columns]

# %%
pd.merge(df1,df2,on = 'imdb_id')
# Out:
#    adult                     backdrop_path  \
# 0  False  /kMzU4PkXcKcDMngCxXji0BbVXsu.jpg
#
#                                belongs_to_collection     budget  \
# 0  {u'backdrop_path': u'/jc1Sh8U6dvWv9rHaRl8aosTA...  180000000
#
#                                             genres_x  \
# 0  [{u'id': 12, u'name': u'Adventure'}, {u'id': 2...
#
#                           homepage      id  imdb_id original_language  \
# 0  http://www.fantasticbeasts.com/  259316  3183660                en
#
#                             original_title  ...   \
# 0  Fantastic Beasts and Where to Find Them  ...
#
#                                         plot outline  \
# 0  The adventures of writer Newt Scamander in New...
#
#            production companies rating runtimes  \
# 0  [Heyday Films, Warner Bros.]    7.5    [133]
#
#                      smart canonical title  \
# 0  Fantastic Beasts and Where to Find Them
#
#                   smart long imdb canonical title  \
# 0  Fantastic Beasts and Where to Find Them (2016)
#
#                                sound mix  \
# 0  [Datasat, Dolby Digital, Dolby Atmos]
#
#                                    title_y   votes  year
# 0  Fantastic Beasts and Where to Find Them  205785  2016
#
# [1 rows x 53 columns]

# %% [markdown]
# # Load files from TMDb and IMDb and merge them

# %%
def

# %% [markdown]
# # Get person Info

# %%
str(favorite_movie_imdb['director'])
# Out:
# '[<Person id:0946734[http] name:_Yates, David_>]'

# %%
person = ia.get_person('0946734')

# %%
for k in person.keys():
    print k,'\t\t',person[k] ,'\n'
# Out:
# name 		David Yates
#
# producer 		[<Movie id:0918940[http] title:_The Legend of Tarzan (2016)_>, <Movie id:2568204[http] title:_"Tyrant" (2014)_>, <Movie id:1029224[http] title:_Tale of Three Seaside Towns (1995)_>, <Movie id:0466194[http] title:_When I Was a Girl (1988)_>]
#
# in development 		[<Movie id:3234608[http] title:_Who Is Jake Ellis? (????)_>]
#
# self 		[<Movie id:0192897[http] title:_"Film 2017" (2016)_>, <Movie id:6267730[http] title:_The Legend of Tarzan: Creating the Virtual Jungle (2016)_>, <Movie id:6267696[http] title:_The Legend of Tarzan: Tarzan Reborn (2016)_>, <Movie id:0911896[http] title:_"Made in Hollywood" (2010)_>, <Movie id:1245693[http] title:_"Made in Hollywood: Teen Edition" (2011)_>, <Movie id:1415098[http] title:_"Piers Morgan's Life Stories" (2015)_>, <Movie id:2339417[http] title:_Creating the World of Harry Potter, Part 8: Growing Up (2012)_>, <Movie id:2917244[http] title:_Warner Bros. Studio Tour London: The Making of Harry Potter (2012)_>, <Movie id:2006673[http] title:_50 Greatest Harry Potter Moments (2011)_>, <Movie id:1612376[http] title:_"Janela Indiscreta" (2011)_>, <Movie id:2063020[http] title:_"1st Look" (2011)_>, <Movie id:0390699[http] title:_"Días de cine" (2009)_>, <Movie id:2316746[http] title:_"Acesso MTV" (2011)_>, <Movie id:2339411[http] title:_Creating the World of Harry Potter, Part 5: Evolution (2011)_>, <Movie id:2339413[http] title:_Creating the World of Harry Potter, Part 6: Magical Effects (2011)_>, <Movie id:1775795[http] title:_ITV at the Movies (2010)_>, <Movie id:2339409[http] title:_Creating the World of Harry Potter, Part 3: Creatures (2010)_>, <Movie id:0318220[http] title:_HBO First Look (2007)_>, <Movie id:1310630[http] title:_The 2008 European Film Awards (2008)_>, <Movie id:1111768[http] title:_Achter de schermen bij 'Harry Potter en de orde van de feniks' (2007)_>, <Movie id:1069278[http] title:_"Das große RTL Special zum Film" (2007)_>, <Movie id:1065088[http] title:_The Hidden Secrets of Harry Potter (2007)_>, <Movie id:1252376[http] title:_2nd Annual Directors Guild of Great Britain DGGB Awards (2005)_>, <Movie id:0407487[http] title:_1st Annual Directors Guild of Great Britain DGGB Awards (2004)_>]
#
# writer 		[<Movie id:0475782[http] title:_The Weaver's Wife (1991)_>, <Movie id:0466194[http] title:_When I Was a Girl (1988)_>]
#
# mini biography 		[u'David Yates was born on October 8, 1963 in St. Helens, Merseyside, England. He is a director and producer, known for Harry Potter and the Deathly Hallows: Part 2 (2011), Harry Potter and the Order of the Phoenix (2007) and Harry Potter and the Half-Blood Prince (2009).::Anonymous']
#
# actor 		[<Movie id:1454262[http] title:_"Hollywood's Best Film Directors" (2014)_>]
#
# director 		[<Movie id:6149054[http] title:_Fantastic Beasts and Where to Find Them 5 (2024)_>, <Movie id:6149052[http] title:_Fantastic Beasts and Where to Find Them 4 (2022)_>, <Movie id:4123432[http] title:_Fantastic Beasts and Where to Find Them 3 (2020)_>, <Movie id:4123430[http] title:_Fantastic Beasts and Where to Find Them 2 (2018)_>, <Movie id:3183660[http] title:_Fantastic Beasts and Where to Find Them (2016)_>, <Movie id:0918940[http] title:_The Legend of Tarzan (2016)_>, <Movie id:2568204[http] title:_"Tyrant" (2014)_>, <Movie id:1201607[http] title:_Harry Potter and the Deathly Hallows: Part 2 (2011)_>, <Movie id:0926084[http] title:_Harry Potter and the Deathly Hallows: Part 1 (2010)_>, <Movie id:0417741[http] title:_Harry Potter and the Half-Blood Prince (2009)_>, <Movie id:0373889[http] title:_Harry Potter and the Order of the Phoenix (2007)_>, <Movie id:0443518[http] title:_The Girl in the Café (2005) (TV)_>, <Movie id:0419365[http] title:_Sex Traffic (2004)_>, <Movie id:0379053[http] title:_The Young Visiters (2003) (TV)_>, <Movie id:0362192[http] title:_State of Play (2003)_>, <Movie id:0351635[http] title:_Rank (2002)_>, <Movie id:0300879[http] title:_The Way We Live Now (2001)_>, <Movie id:0265755[http] title:_The Sins (2000)_>, <Movie id:0127933[http] title:_The Tichborne Claimant (1998)_>, <Movie id:0463359[http] title:_Punch (1996)_>, <Movie id:1029224[http] title:_Tale of Three Seaside Towns (1995)_>, <Movie id:0084987[http] title:_"The Bill" (1994)_>, <Movie id:0483846[http] title:_Moving Pictures (1994)_>, <Movie id:0475594[http] title:_Good Looks (1992)_>, <Movie id:0475677[http] title:_Oranges and Lemons (1991)_>, <Movie id:0475782[http] title:_The Weaver's Wife (1991)_>, <Movie id:0466194[http] title:_When I Was a Girl (1988)_>]
#
# birth notes 		St. Helens, Merseyside, England, UK
#
# thanks 		[<Movie id:1571403[http] title:_Harry Potter and the Deathly Hallows: Part I (2010) (VG)_>]
#
# headshot 		https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2NTU4NjY4M15BMl5BanBnXkFtZTYwNjIxOTI1._V1_UY317_CR10,0,214,317_AL_.jpg
#
# imdbIndex 		II
#
# birth date 		8 October 1963
#
# canonical name 		Yates, David
#
# long imdb name 		David Yates (II)
#
# long imdb canonical name 		Yates, David (II)
#
# full-size headshot 		https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2NTU4NjY4M15BMl5BanBnXkFtZTYwNjIxOTI1._V1_UY317_CR10,0,214,317_AL_.jpg
